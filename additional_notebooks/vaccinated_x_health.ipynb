# %%
import pandas as pd

# %%
df7 = pd.read_csv('./betterlifeindex_2019.csv')

df7 = pd.read_csv('betterlifeindex_2019.csv')  
df7.rename(columns={"Country": "Country Name"}, inplace=True)
df7 = df7[["LOCATION", "Country Name","Indicator", "Value"]].loc[(df7["Inequality"]=="Total")]
df8 = df7.loc[(df7["Indicator"]=="Life expectancy")][["Country Name", "LOCATION", "Value"]]
df8.rename(columns={"Value": "Life_expectancy_2019"}, inplace=True)
df9 = df7.loc[(df7["Indicator"]=="Homicide rate")][["Country Name", "LOCATION", "Value"]]
df9.rename(columns={"Value": "Homicide_rate_2019"}, inplace=True)
df10 = df7.loc[(df7["Indicator"]=="Life satisfaction")][["Country Name", "LOCATION", "Value"]]
df10.rename(columns={"Value": "Life satisfaction_2019"}, inplace=True)
df11 = df7.loc[(df7["Indicator"]=="Employees working very long hours")][["Country Name", "LOCATION", "Value"]]
df11.rename(columns={"Value": "Employees_working_hours_2019"}, inplace=True)
df12 = df7.loc[(df7["Indicator"]=="Time devoted to leisure and personal care")][["Country Name", "LOCATION", "Value"]]
df12.rename(columns={"Value": "leisure_and_personal_care_2019"}, inplace=True)
df13 = df7.loc[(df7["Indicator"]=="Voter turnout")][["Country Name", "LOCATION", "Value"]]
df13.rename(columns={"Value": "Voter_turnout_2019"}, inplace=True)
df7 = df7.loc[(df7["Indicator"]=="Self-reported health")][["Country Name", "LOCATION", "Value"]]
df7.rename(columns={"Value": "Self-reported_health_2019"}, inplace=True)
df7 = df7.set_index('Country Name')
df7
# Out:
#                 LOCATION  Self-reported_health_2019
# Country Name
# Australia            AUS                       85.0
# Austria              AUT                       70.0
# Belgium              BEL                       74.0
# Canada               CAN                       88.0
# Czech Republic       CZE                       60.0
# Denmark              DNK                       71.0
# Finland              FIN                       70.0
# France               FRA                       66.0
# Germany              DEU                       65.0
# Greece               GRC                       74.0
# Hungary              HUN                       60.0
# Iceland              ISL                       76.0
# Ireland              IRL                       83.0
# Italy                ITA                       71.0
# Japan                JPN                       36.0
# Korea                KOR                       33.0
# Luxembourg           LUX                       69.0
# Mexico               MEX                       66.0
# Netherlands          NLD                       76.0
# New Zealand          NZL                       88.0
# Norway               NOR                       77.0
# Poland               POL                       58.0
# Portugal             PRT                       48.0
# Slovak Republic      SVK                       66.0
# Spain                ESP                       72.0
# Sweden               SWE                       75.0
# Switzerland          CHE                       78.0
# Turkey               TUR                       69.0
# United Kingdom       GBR                       69.0
# United States        USA                       88.0
# Chile                CHL                       57.0
# Estonia              EST                       53.0
# Israel               ISR                       84.0
# Latvia               LVA                       47.0
# Russia               RUS                       43.0
# Slovenia             SVN                       64.0
# OECD - Total        OECD                       69.0
# Lithuania            LTU                       43.0

# %%
vax_rate = pd.read_csv('./COVID-19_vaccination_rates.csv')

# %%
vax_rate = vax_rate[['location', 'people_fully_vaccinated_per_hundred']].groupby(['location']).max()
vax_rate
# Out:
#                    people_fully_vaccinated_per_hundred
# location
# Afghanistan                                       8.95
# Africa                                            7.72
# Albania                                          34.15
# Algeria                                          12.08
# Andorra                                          64.04
# ...                                                ...
# Wallis and Futuna                                53.39
# World                                            45.05
# Yemen                                             1.20
# Zambia                                            4.08
# Zimbabwe                                         19.39
#
# [235 rows x 1 columns]

# %%
df = pd.merge(vax_rate, df7, left_index=True, right_index=True).rename(columns={'Deaths/1M population': 'deaths_per_million'})
df
# Out:
#                 people_fully_vaccinated_per_hundred LOCATION  \
# Australia                                     74.26      AUS
# Austria                                       67.50      AUT
# Belgium                                       75.03      BEL
# Canada                                        76.59      CAN
# Chile                                         84.64      CHL
# Denmark                                       77.04      DNK
# Estonia                                       60.19      EST
# Finland                                       73.13      FIN
# France                                        70.52      FRA
# Germany                                       68.56      DEU
# Greece                                        64.70      GRC
# Hungary                                       61.02      HUN
# Iceland                                       82.08      ISL
# Ireland                                       76.37      IRL
# Israel                                        62.28      ISR
# Italy                                         73.23      ITA
# Japan                                         77.66      JPN
# Latvia                                        65.30      LVA
# Lithuania                                     66.85      LTU
# Luxembourg                                    67.69      LUX
# Mexico                                        50.32      MEX
# Netherlands                                   74.08      NLD
# New Zealand                                   72.62      NZL
# Norway                                        70.66      NOR
# Poland                                        54.53      POL
# Portugal                                      88.63      PRT
# Russia                                        40.82      RUS
# Slovenia                                      56.00      SVN
# Spain                                         80.60      ESP
# Sweden                                        71.13      SWE
# Switzerland                                   65.84      CHE
# Turkey                                        59.71      TUR
# United Kingdom                                68.34      GBR
# United States                                 59.90      USA
#
#                 Self-reported_health_2019
# Australia                            85.0
# Austria                              70.0
# Belgium                              74.0
# Canada                               88.0
# Chile                                57.0
# Denmark                              71.0
# Estonia                              53.0
# Finland                              70.0
# France                               66.0
# Germany                              65.0
# Greece                               74.0
# Hungary                              60.0
# Iceland                              76.0
# Ireland                              83.0
# Israel                               84.0
# Italy                                71.0
# Japan                                36.0
# Latvia                               47.0
# Lithuania                            43.0
# Luxembourg                           69.0
# Mexico                               66.0
# Netherlands                          76.0
# New Zealand                          88.0
# Norway                               77.0
# Poland                               58.0
# Portugal                             48.0
# Russia                               43.0
# Slovenia                             64.0
# Spain                                72.0
# Sweden                               75.0
# Switzerland                          78.0
# Turkey                               69.0
# United Kingdom                       69.0
# United States                        88.0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['Self-reported_health_2019'], df['people_fully_vaccinated_per_hundred'])
plt.xlabel('Deaths per Million')
plt.ylabel('Vaccinations per Hundred')
plt.show()
