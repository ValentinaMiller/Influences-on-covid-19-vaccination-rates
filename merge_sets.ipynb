# %%
import pandas as pd

# %%
datasets = {
    'rates': pd.read_csv('COVID-19_vaccination_rates.csv'),
    'gdp': pd.read_csv('gdp.csv'),
    'edu': pd.read_csv('higher_education_rate.csv'),
    'regime': pd.read_csv('political_regime.csv'),
    'gov_trst': pd.read_csv('trust_in_government.csv'),
    'unemploy': pd.read_csv('unemployment_rate.csv')
}

# %%
names = set(datasets['rates'].location.unique()) 
names &= set(datasets['gdp']['Country Name'].unique()) 
names &= set(datasets['edu']['Country Name'].unique())
#names &= set(datasets['regime']['Case Name'].unique())
#names &= set(datasets['gov_trst']['LOCATION'].unique())
names &= set(datasets['unemploy']['Country Name'].unique())
names
# Out:
# {'Afghanistan',
#  'Albania',
#  'Algeria',
#  'Andorra',
#  'Angola',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'British Virgin Islands',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Cayman Islands',
#  'Central African Republic',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros',
#  'Costa Rica',
#  "Cote d'Ivoire",
#  'Croatia',
#  'Cuba',
#  'Curacao',
#  'Cyprus',
#  'Denmark',
#  'Djibouti',
#  'Dominica',
#  'Dominican Republic',
#  'Ecuador',
#  'El Salvador',
#  'Equatorial Guinea',
#  'Estonia',
#  'Eswatini',
#  'Ethiopia',
#  'European Union',
#  'Fiji',
#  'Finland',
#  'France',
#  'French Polynesia',
#  'Gabon',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Gibraltar',
#  'Greece',
#  'Greenland',
#  'Grenada',
#  'Guatemala',
#  'Guinea',
#  'Guinea-Bissau',
#  'Guyana',
#  'Haiti',
#  'High income',
#  'Honduras',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Iraq',
#  'Ireland',
#  'Isle of Man',
#  'Israel',
#  'Italy',
#  'Jamaica',
#  'Japan',
#  'Jordan',
#  'Kazakhstan',
#  'Kenya',
#  'Kiribati',
#  'Kosovo',
#  'Kuwait',
#  'Latvia',
#  'Lebanon',
#  'Lesotho',
#  'Liberia',
#  'Libya',
#  'Liechtenstein',
#  'Lithuania',
#  'Low income',
#  'Lower middle income',
#  'Luxembourg',
#  'Madagascar',
#  'Malawi',
#  'Malaysia',
#  'Maldives',
#  'Mali',
#  'Malta',
#  'Mauritania',
#  'Mauritius',
#  'Mexico',
#  'Moldova',
#  'Monaco',
#  'Mongolia',
#  'Montenegro',
#  'Morocco',
#  'Mozambique',
#  'Myanmar',
#  'Namibia',
#  'Nauru',
#  'Nepal',
#  'Netherlands',
#  'New Caledonia',
#  'New Zealand',
#  'Nicaragua',
#  'Niger',
#  'Nigeria',
#  'North America',
#  'North Macedonia',
#  'Norway',
#  'Oman',
#  'Pakistan',
#  'Panama',
#  'Papua New Guinea',
#  'Paraguay',
#  'Peru',
#  'Philippines',
#  'Poland',
#  'Portugal',
#  'Qatar',
#  'Romania',
#  'Rwanda',
#  'Samoa',
#  'San Marino',
#  'Sao Tome and Principe',
#  'Saudi Arabia',
#  'Senegal',
#  'Serbia',
#  'Seychelles',
#  'Sierra Leone',
#  'Singapore',
#  'Sint Maarten (Dutch part)',
#  'Slovenia',
#  'Solomon Islands',
#  'Somalia',
#  'South Africa',
#  'South Sudan',
#  'Spain',
#  'Sri Lanka',
#  'Sudan',
#  'Suriname',
#  'Sweden',
#  'Switzerland',
#  'Tajikistan',
#  'Tanzania',
#  'Thailand',
#  'Togo',
#  'Tonga',
#  'Trinidad and Tobago',
#  'Tunisia',
#  'Turkey',
#  'Turkmenistan',
#  'Turks and Caicos Islands',
#  'Tuvalu',
#  'Uganda',
#  'Ukraine',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States',
#  'Upper middle income',
#  'Uruguay',
#  'Uzbekistan',
#  'Vanuatu',
#  'Vietnam',
#  'World',
#  'Zambia',
#  'Zimbabwe'}

# %%
set(datasets['regime']['Case Name'].unique())
# Out:
# {'Afghanistan 01-09',
#  'Afghanistan 09-NA',
#  'Afghanistan 29-73',
#  'Afghanistan 73-78',
#  'Afghanistan 78-92',
#  'Afghanistan 92-96',
#  'Afghanistan 96-01',
#  'Albania 44-91',
#  'Albania 91-NA',
#  'Algeria 62-92',
#  'Algeria 92-NA',
#  'Angola 75-NA',
#  'Argentina 43-46',
#  'Argentina 46-51',
#  'Argentina 51-55',
#  'Argentina 55-58',
#  'Argentina 58-66',
#  'Argentina 66-73',
#  'Argentina 73-76',
#  'Argentina 76-83',
#  'Argentina 83-NA',
#  'Armenia 91-94',
#  'Armenia 94-98',
#  'Armenia 98-NA',
#  'Australia 01-NA',
#  'Austria 45-NA',
#  'Azerbaijan 91-92',
#  'Azerbaijan 92-93',
#  'Azerbaijan 93-NA',
#  'Bangladesh 07-08',
#  'Bangladesh 08-NA',
#  'Bangladesh 71-75',
#  'Bangladesh 75-82',
#  'Bangladesh 82-90',
#  'Bangladesh 90-07',
#  'Belarus 91-94',
#  'Belarus 94-NA',
#  'Belgium 20-NA',
#  'Benin 60-63',
#  'Benin 63-65',
#  'Benin 65-67',
#  'Benin 67-69',
#  'Benin 69-70',
#  'Benin 70-72',
#  'Benin 72-90',
#  'Benin 90-91',
#  'Benin 91-NA',
#  'Bolivia 43-46',
#  'Bolivia 46-51',
#  'Bolivia 51-52',
#  'Bolivia 52-64',
#  'Bolivia 64-69',
#  'Bolivia 69-71',
#  'Bolivia 71-79',
#  'Bolivia 79-80',
#  'Bolivia 80-82',
#  'Bolivia 82-NA',
#  'Bosnia and Herzegovina 92-95',
#  'Bosnia and Herzegovina 95-09',
#  'Botswana 66-NA',
#  'Brazil 45-64',
#  'Brazil 64-85',
#  'Brazil 85-NA',
#  'Bulgaria 44-90',
#  'Bulgaria 90-NA',
#  'Burkina Faso 60-66',
#  'Burkina Faso 66-80',
#  'Burkina Faso 80-82',
#  'Burkina Faso 82-87',
#  'Burkina Faso 87-NA',
#  'Burundi 03-05',
#  'Burundi 05-NA',
#  'Burundi 62-66',
#  'Burundi 66-87',
#  'Burundi 87-93',
#  'Burundi 93-96',
#  'Burundi 96-03',
#  'Cambodia 53-70',
#  'Cambodia 70-75',
#  'Cambodia 75-79',
#  'Cambodia 79-NA',
#  'Cameroon 60-83',
#  'Cameroon 83-NA',
#  'Canada 21-NA',
#  'Cen African Rep 03-NA',
#  'Cen African Rep 60-65',
#  'Cen African Rep 65-79',
#  'Cen African Rep 79-81',
#  'Cen African Rep 81-93',
#  'Cen African Rep 93-03',
#  'Chad 60-75',
#  'Chad 75-79',
#  'Chad 79-82',
#  'Chad 82-90',
#  'Chad 90-NA',
#  'Chile 32-73',
#  'Chile 73-89',
#  'Chile 89-NA',
#  'China 46-49',
#  'China 49-NA',
#  'Colombia 34-49',
#  'Colombia 49-53',
#  'Colombia 53-58',
#  'Colombia 58-NA',
#  'Congo-Brz  97-NA',
#  'Congo-Brz 60-63',
#  'Congo-Brz 63-68',
#  'Congo-Brz 68-91',
#  'Congo-Brz 91-92',
#  'Congo-Brz 92-97',
#  'Congo/Zaire 60-97',
#  'Congo/Zaire 97-NA',
#  'Costa Rica 19-48',
#  'Costa Rica 48-49',
#  'Costa Rica 49-NA',
#  'Croatia 91-NA',
#  'Cuba 44-52',
#  'Cuba 52-59',
#  'Cuba 59-NA',
#  'Czech Republic 93-NA',
#  'Czechoslovakia 46-48',
#  'Czechoslovakia 48-89',
#  'Czechoslovakia 89-93',
#  'Denmark 01-NA',
#  'Dominican Rep 30-62',
#  'Dominican Rep 62-63',
#  'Dominican Rep 63-65',
#  'Dominican Rep 65-66',
#  'Dominican Rep 66-78',
#  'Dominican Rep 78-NA',
#  'Ecuador 44-47',
#  'Ecuador 47-48',
#  'Ecuador 48-63',
#  'Ecuador 63-66',
#  'Ecuador 66-68',
#  'Ecuador 68-70',
#  'Ecuador 70-72',
#  'Ecuador 72-79',
#  'Ecuador 79-NA',
#  'Egypt 22-52',
#  'Egypt 52-NA',
#  'El Salvador 31-48',
#  'El Salvador 48-82',
#  'El Salvador 82-94',
#  'El Salvador 94-NA',
#  'Eritrea 93-NA',
#  'Estonia 91-NA',
#  'Ethiopia 1889-1974',
#  'Ethiopia 74-91',
#  'Ethiopia 91-NA',
#  'Finland 45-NA',
#  'France 1875-NA',
#  'Gabon 60-NA',
#  'Gambia 65-94',
#  'Gambia 94-NA',
#  'Georgia 03-04',
#  'Georgia 04-NA',
#  'Georgia 91-92',
#  'Georgia 92-03',
#  'Germany 49-NA',
#  'Germany, East 49-90',
#  'Ghana 00-NA',
#  'Ghana 56-60',
#  'Ghana 60-66',
#  'Ghana 66-69',
#  'Ghana 69-72',
#  'Ghana 72-79',
#  'Ghana 79-81',
#  'Ghana 81-00',
#  'Greece 44-46',
#  'Greece 47-67',
#  'Greece 67-74',
#  'Greece 74-NA',
#  'Guatemala 44-54',
#  'Guatemala 54-58',
#  'Guatemala 58-63',
#  'Guatemala 63-66',
#  'Guatemala 66-70',
#  'Guatemala 70-85',
#  'Guatemala 85-95',
#  'Guatemala 95-NA',
#  'Guinea 08-10',
#  'Guinea 58-84',
#  'Guinea 84-08',
#  'Guinea Bissau 00-02',
#  'Guinea Bissau 02-03',
#  'Guinea Bissau 03-05',
#  'Guinea Bissau 05-NA',
#  'Guinea Bissau 74-80',
#  'Guinea Bissau 80-99',
#  'Guinea Bissau 99-00',
#  'Haiti 04-06',
#  'Haiti 06-NA',
#  'Haiti 41-46',
#  'Haiti 46-50',
#  'Haiti 50-56',
#  'Haiti 56-57',
#  'Haiti 57-86',
#  'Haiti 86-88',
#  'Haiti 88-90',
#  'Haiti 90-91',
#  'Haiti 91-94',
#  'Haiti 94-99',
#  'Haiti 99-04',
#  'Honduras 33-56',
#  'Honduras 56-57',
#  'Honduras 57-63',
#  'Honduras 63-71',
#  'Honduras 71-72',
#  'Honduras 72-81',
#  'Honduras 81-NA',
#  'Hungary 45-47',
#  'Hungary 47-90',
#  'Hungary 90-NA',
#  'Iceland 45-NA',
#  'India 47-NA',
#  'Indonesia 49-66',
#  'Indonesia 66-99',
#  'Indonesia 99-NA',
#  'Iran 25-79',
#  'Iran 79-NA',
#  'Iraq 03-10',
#  'Iraq 32-58',
#  'Iraq 58-63',
#  'Iraq 63-68',
#  'Iraq 68-79',
#  'Iraq 79-03',
#  'Ireland 21-NA',
#  'Israel 48-NA',
#  'Italy 46-NA',
#  'Ivory Coast 00-NA',
#  'Ivory Coast 60-99',
#  'Ivory Coast 99-00',
#  'Japan 46-NA',
#  'Jordan 46-NA',
#  'Kazakhstan 91-NA',
#  'Kenya 02-NA',
#  'Kenya 63-02',
#  'Korea North 48-NA',
#  'Korea, South 48-60',
#  'Korea, South 60-61',
#  'Korea, South 61-87',
#  'Korea, South 87-NA',
#  'Kuwait 61-NA',
#  'Kyrgyzstan 05-10',
#  'Kyrgyzstan 91-05',
#  'Laos 53-59',
#  'Laos 59-60',
#  'Laos 60-62',
#  'Laos 62-73',
#  'Laos 73-75',
#  'Laos 75-NA',
#  'Latvia 91-NA',
#  'Lebanon 05-NA',
#  'Lebanon 43-76',
#  'Lebanon 76-05',
#  'Lesotho 65-70',
#  'Lesotho 70-86',
#  'Lesotho 86-93',
#  'Lesotho 93-NA',
#  'Liberia 03-05',
#  'Liberia 05-NA',
#  'Liberia 44-80',
#  'Liberia 80-90',
#  'Liberia 90-97',
#  'Liberia 97-03',
#  'Libya 51-69',
#  'Libya 69-NA',
#  'Lietchtenstein 1870-NA',
#  'Lithuania 91-NA',
#  'Luxemburg 1870-NA',
#  'Macedonia 91-NA',
#  'Madagascar 09-NA',
#  'Madagascar 60-72',
#  'Madagascar 72-75',
#  'Madagascar 75-93',
#  'Madagascar 93-09',
#  'Malawi 64-94',
#  'Malawi 94-NA',
#  'Malaysia 57-NA',
#  'Mali 60-68',
#  'Mali 68-91',
#  'Mali 91-92',
#  'Mali 92-NA',
#  'Mauritania 05-07',
#  'Mauritania 07-08',
#  'Mauritania 08-NA',
#  'Mauritania 60-78',
#  'Mauritania 78-05',
#  'Mauritius 68-NA',
#  'Mexico 00-NA',
#  'Mexico 15-00',
#  'Moldova 91-NA',
#  'Mongolia 21-93',
#  'Mongolia 93-NA',
#  'Montenegro 06-NA',
#  'Morocco 56-NA',
#  'Mozambique 75-NA',
#  'Myanmar 48-58',
#  'Myanmar 58-60',
#  'Myanmar 60-62',
#  'Myanmar 62-88',
#  'Myanmar 88-NA',
#  'Namibia 90-NA',
#  'Nepal 02-06',
#  'Nepal 06-NA',
#  'Nepal 1846-1951',
#  'Nepal 51-91',
#  'Nepal 91-02',
#  'Netherlands 1870-NA',
#  'New Zealand 07-NA',
#  'Nicaragua 36-79',
#  'Nicaragua 79-90',
#  'Nicaragua 90-NA',
#  'Niger 60-74',
#  'Niger 74-91',
#  'Niger 91-93',
#  'Niger 93-96',
#  'Niger 96-99',
#  'Niger 99-NA',
#  'Nigeria 60-66',
#  'Nigeria 66-79',
#  'Nigeria 79-83',
#  'Nigeria 83-93',
#  'Nigeria 93-99',
#  'Nigeria 99-NA',
#  'Norway 1885-NA',
#  'Oman 1741-NA',
#  'Pakistan 08-NA',
#  'Pakistan 47-58',
#  'Pakistan 58-71',
#  'Pakistan 71-75',
#  'Pakistan 75-77',
#  'Pakistan 77-88',
#  'Pakistan 88-99',
#  'Pakistan 99-08',
#  'Panama 45-49',
#  'Panama 49-51',
#  'Panama 51-52',
#  'Panama 52-53',
#  'Panama 53-55',
#  'Panama 55-68',
#  'Panama 68-82',
#  'Panama 82-89',
#  'Panama 89-NA',
#  'Paraguay 40-48',
#  'Paraguay 48-54',
#  'Paraguay 54-93',
#  'Paraguay 93-NA',
#  'Peru 00-01',
#  'Peru 01-NA',
#  'Peru 45-48',
#  'Peru 48-56',
#  'Peru 56-62',
#  'Peru 62-63',
#  'Peru 63-68',
#  'Peru 68-80',
#  'Peru 80-92',
#  'Peru 92-00',
#  'Philippines 46-72',
#  'Philippines 72-86',
#  'Philippines 86-NA',
#  'Poland 44-89',
#  'Poland 89-NA',
#  'Portugal 26-74',
#  'Portugal 74-76',
#  'Portugal 76-NA',
#  'Romania 45-89',
#  'Romania 89-90',
#  'Romania 90-NA',
#  'Russia 91-93',
#  'Russia 93-NA',
#  'Rwanda 62-73',
#  'Rwanda 73-94',
#  'Rwanda 94-NA',
#  'Saudi Arabia 27-NA',
#  'Senegal 00-NA',
#  'Senegal 60-00',
#  'Serbia 00-NA',
#  'Serbia 91-00',
#  'Sierra Leone 61-67',
#  'Sierra Leone 67-68',
#  'Sierra Leone 68-92',
#  'Sierra Leone 92-96',
#  'Sierra Leone 96-97',
#  'Sierra Leone 97-98',
#  'Sierra Leone 98-NA',
#  'Singapore 65-NA',
#  'Slovakia 93-NA',
#  'Slovenia 91-NA',
#  'Somalia 60-69',
#  'Somalia 69-91',
#  'Somalia 91-NA',
#  'South Africa 10-94',
#  'South Africa 94-NA',
#  'South Vietnam 54-63',
#  'South Vietnam 63-75',
#  'South Yemen 67-90',
#  'Soviet Union 17-91',
#  'Spain 39-76',
#  'Spain 76-77',
#  'Spain 77-NA',
#  'Sri Lanka 48-78',
#  'Sri Lanka 78-94',
#  'Sri Lanka 94-NA',
#  'Sudan 56-58',
#  'Sudan 58-64',
#  'Sudan 64-65',
#  'Sudan 65-69',
#  'Sudan 69-85',
#  'Sudan 85-86',
#  'Sudan 86-89',
#  'Sudan 89-NA',
#  'Swaziland 68-NA',
#  'Sweden 19-NA',
#  'Switzerland 1870-NA',
#  'Syria 46-47',
#  'Syria 47-49',
#  'Syria 49-51',
#  'Syria 51-54',
#  'Syria 54-57',
#  'Syria 57-58',
#  'Syria 58-61',
#  'Syria 61-62',
#  'Syria 62-63',
#  'Syria 63-NA',
#  'Taiwan 00-NA',
#  'Taiwan 49-00',
#  'Tajikistan 91-NA',
#  'Tanzania 60-64',
#  'Tanzania 64-NA',
#  'Thailand 06-07',
#  'Thailand 07-NA',
#  'Thailand 44-47',
#  'Thailand 47-57',
#  'Thailand 57-73',
#  'Thailand 73-75',
#  'Thailand 75-76',
#  'Thailand 76-88',
#  'Thailand 88-91',
#  'Thailand 91-92',
#  'Thailand 92-06',
#  'Togo 60-63',
#  'Togo 67-NA',
#  'Tunisia 56-NA',
#  'Turkey 23-50',
#  'Turkey 50-57',
#  'Turkey 57-60',
#  'Turkey 60-61',
#  'Turkey 61-80',
#  'Turkey 80-83',
#  'Turkey 83-NA',
#  'Turkmenistan 91-NA',
#  'UAE 71-NA',
#  'UK 11-NA',
#  'USA 1871-NA',
#  'Uganda 62-66',
#  'Uganda 66-71',
#  'Uganda 71-79',
#  'Uganda 79-80',
#  'Uganda 80-85',
#  'Uganda 85-86',
#  'Uganda 86-NA',
#  'Ukraine 91-NA',
#  'Uruguay 42-73',
#  'Uruguay 73-84',
#  'Uruguay 84-NA',
#  'Uzbekistan 91-NA',
#  'Venezuela 05-NA',
#  'Venezuela 45-47',
#  'Venezuela 47-48',
#  'Venezuela 48-58',
#  'Venezuela 58-05',
#  'Vietnam 54-NA',
#  'Yemen 18-62',
#  'Yemen 62-67',
#  'Yemen 67-74',
#  'Yemen 74-78',
#  'Yemen 78-NA',
#  'Yugoslavia 45-90',
#  'Zambia 64-67',
#  'Zambia 67-91',
#  'Zambia 91-96',
#  'Zambia 96-NA',
#  'Zimbabwe 65-80',
#  'Zimbabwe 80-NA',
#  nan}

# %%
set(datasets['gov_trst']['LOCATION'].unique())
# Out:
# {'AUS',
#  'AUT',
#  'BEL',
#  'BRA',
#  'CAN',
#  'CHE',
#  'CHL',
#  'COL',
#  'CRI',
#  'CZE',
#  'DEU',
#  'DNK',
#  'ESP',
#  'EST',
#  'FIN',
#  'FRA',
#  'GBR',
#  'GRC',
#  'HUN',
#  'IRL',
#  'ISL',
#  'ISR',
#  'ITA',
#  'JPN',
#  'KOR',
#  'LTU',
#  'LUX',
#  'LVA',
#  'MEX',
#  'NLD',
#  'NOR',
#  'NZL',
#  'POL',
#  'PRT',
#  'RUS',
#  'SVK',
#  'SVN',
#  'SWE',
#  'TUR',
#  'USA',
#  'ZAF'}

# %%
# Convert country code to name 
codes = pd.read_csv('country_codes.csv')

lookup_table = codes[['Alpha-3 code','Country']]
lookup_table
# Out:
#     Alpha-3 code            Country
# 0          "AFG"        Afghanistan
# 1          "ALB"            Albania
# 2          "DZA"            Algeria
# 3          "ASM"     American Samoa
# 4          "AND"            Andorra
# ..           ...                ...
# 251        "WLF"  Wallis and Futuna
# 252        "ESH"     Western Sahara
# 253        "YEM"              Yemen
# 254        "ZMB"             Zambia
# 255        "ZWE"           Zimbabwe
#
# [256 rows x 2 columns]

# %%
lookup_table.loc[lookup_table['Alpha-3 code'] == ' "AFG"']
# Out:
#   Alpha-3 code      Country
# 0        "AFG"  Afghanistan

# %%
for c in datasets['gov_trst']['LOCATION']:
    print(lookup_table.loc[lookup_table['Alpha-3 code'] == ' "{}"'.format(c)])
# Out:
#    Alpha-3 code    Country
# 12        "AUS"  Australia
#    Alpha-3 code    Country
# 12        "AUS"  Australia
#    Alpha-3 code    Country
# 12        "AUS"  Australia
#    Alpha-3 code    Country
# 12        "AUS"  Australia
#    Alpha-3 code    Country
# 12        "AUS"  Australia
#    Alpha-3 code    Country
# 12        "AUS"  Australia
#    Alpha-3 code    Country
# 12        "AUS"  Australia
#    Alpha-3 code    Country
# 12        "AUS"  Australia
#    Alpha-3 code    Country
# 12        "AUS"  Australia
#    Alpha-3 code    Country
# 12        "AUS"  Australia
#    Alpha-3 code    Country
# 12        "AUS"  Australia
#    Alpha-3 code    Country
# 12        "AUS"  Australia
#    Alpha-3 code    Country
# 12        "AUS"  Australia
#    Alpha-3 code    Country
# 12        "AUS"  Australia
#    Alpha-3 code  Country
# 13        "AUT"  Austria
#    Alpha-3 code  Country
# 13        "AUT"  Austria
#    Alpha-3 code  Country
# 13        "AUT"  Austria
#    Alpha-3 code  Country
# 13        "AUT"  Austria
#    Alpha-3 code  Country
# 13        "AUT"  Austria
#    Alpha-3 code  Country
# 13        "AUT"  Austria
#    Alpha-3 code  Country
# 13        "AUT"  Austria
#    Alpha-3 code  Country
# 13        "AUT"  Austria
#    Alpha-3 code  Country
# 13        "AUT"  Austria
#    Alpha-3 code  Country
# 13        "AUT"  Austria
#    Alpha-3 code  Country
# 13        "AUT"  Austria
#    Alpha-3 code  Country
# 13        "AUT"  Austria
#    Alpha-3 code  Country
# 13        "AUT"  Austria
#    Alpha-3 code  Country
# 13        "AUT"  Austria
#    Alpha-3 code  Country
# 20        "BEL"  Belgium
#    Alpha-3 code  Country
# 20        "BEL"  Belgium
#    Alpha-3 code  Country
# 20        "BEL"  Belgium
#    Alpha-3 code  Country
# 20        "BEL"  Belgium
#    Alpha-3 code  Country
# 20        "BEL"  Belgium
#    Alpha-3 code  Country
# 20        "BEL"  Belgium
#    Alpha-3 code  Country
# 20        "BEL"  Belgium
#    Alpha-3 code  Country
# 20        "BEL"  Belgium
#    Alpha-3 code  Country
# 20        "BEL"  Belgium
#    Alpha-3 code  Country
# 20        "BEL"  Belgium
#    Alpha-3 code  Country
# 20        "BEL"  Belgium
#    Alpha-3 code  Country
# 20        "BEL"  Belgium
#    Alpha-3 code  Country
# 20        "BEL"  Belgium
#    Alpha-3 code  Country
# 20        "BEL"  Belgium
#    Alpha-3 code Country
# 39        "CAN"  Canada
#    Alpha-3 code Country
# 39        "CAN"  Canada
#    Alpha-3 code Country
# 39        "CAN"  Canada
#    Alpha-3 code Country
# 39        "CAN"  Canada
#    Alpha-3 code Country
# 39        "CAN"  Canada
#    Alpha-3 code Country
# 39        "CAN"  Canada
#    Alpha-3 code Country
# 39        "CAN"  Canada
#    Alpha-3 code Country
# 39        "CAN"  Canada
#    Alpha-3 code Country
# 39        "CAN"  Canada
#    Alpha-3 code Country
# 39        "CAN"  Canada
#    Alpha-3 code Country
# 39        "CAN"  Canada
#    Alpha-3 code Country
# 39        "CAN"  Canada
#    Alpha-3 code Country
# 39        "CAN"  Canada
#    Alpha-3 code Country
# 39        "CAN"  Canada
#    Alpha-3 code Country
# 39        "CAN"  Canada
#    Alpha-3 code         Country
# 59        "CZE"  Czech Republic
#    Alpha-3 code         Country
# 59        "CZE"  Czech Republic
#    Alpha-3 code         Country
# 59        "CZE"  Czech Republic
#    Alpha-3 code         Country
# 59        "CZE"  Czech Republic
#    Alpha-3 code         Country
# 59        "CZE"  Czech Republic
#    Alpha-3 code         Country
# 59        "CZE"  Czech Republic
#    Alpha-3 code         Country
# 59        "CZE"  Czech Republic
#    Alpha-3 code         Country
# 59        "CZE"  Czech Republic
#    Alpha-3 code         Country
# 59        "CZE"  Czech Republic
#    Alpha-3 code         Country
# 59        "CZE"  Czech Republic
#    Alpha-3 code         Country
# 59        "CZE"  Czech Republic
#    Alpha-3 code         Country
# 59        "CZE"  Czech Republic
#    Alpha-3 code         Country
# 59        "CZE"  Czech Republic
#    Alpha-3 code  Country
# 60        "DNK"  Denmark
#    Alpha-3 code  Country
# 60        "DNK"  Denmark
#    Alpha-3 code  Country
# 60        "DNK"  Denmark
#    Alpha-3 code  Country
# 60        "DNK"  Denmark
#    Alpha-3 code  Country
# 60        "DNK"  Denmark
#    Alpha-3 code  Country
# 60        "DNK"  Denmark
#    Alpha-3 code  Country
# 60        "DNK"  Denmark
#    Alpha-3 code  Country
# 60        "DNK"  Denmark
#    Alpha-3 code  Country
# 60        "DNK"  Denmark
#    Alpha-3 code  Country
# 60        "DNK"  Denmark
#    Alpha-3 code  Country
# 60        "DNK"  Denmark
#    Alpha-3 code  Country
# 60        "DNK"  Denmark
#    Alpha-3 code  Country
# 60        "DNK"  Denmark
#    Alpha-3 code  Country
# 60        "DNK"  Denmark
#    Alpha-3 code  Country
# 60        "DNK"  Denmark
#    Alpha-3 code  Country
# 74        "FIN"  Finland
#    Alpha-3 code  Country
# 74        "FIN"  Finland
#    Alpha-3 code  Country
# 74        "FIN"  Finland
#    Alpha-3 code  Country
# 74        "FIN"  Finland
#    Alpha-3 code  Country
# 74        "FIN"  Finland
#    Alpha-3 code  Country
# 74        "FIN"  Finland
#    Alpha-3 code  Country
# 74        "FIN"  Finland
#    Alpha-3 code  Country
# 74        "FIN"  Finland
#    Alpha-3 code  Country
# 74        "FIN"  Finland
#    Alpha-3 code  Country
# 74        "FIN"  Finland
#    Alpha-3 code  Country
# 74        "FIN"  Finland
#    Alpha-3 code  Country
# 74        "FIN"  Finland
#    Alpha-3 code  Country
# 74        "FIN"  Finland
#    Alpha-3 code Country
# 75        "FRA"  France
#    Alpha-3 code Country
# 75        "FRA"  France
#    Alpha-3 code Country
# 75        "FRA"  France
#    Alpha-3 code Country
# 75        "FRA"  France
#    Alpha-3 code Country
# 75        "FRA"  France
#    Alpha-3 code Country
# 75        "FRA"  France
#    Alpha-3 code Country
# 75        "FRA"  France
#    Alpha-3 code Country
# 75        "FRA"  France
#    Alpha-3 code Country
# 75        "FRA"  France
#    Alpha-3 code Country
# 75        "FRA"  France
#    Alpha-3 code Country
# 75        "FRA"  France
#    Alpha-3 code Country
# 75        "FRA"  France
#    Alpha-3 code Country
# 75        "FRA"  France
#    Alpha-3 code Country
# 75        "FRA"  France
#    Alpha-3 code Country
# 75        "FRA"  France
#    Alpha-3 code  Country
# 82        "DEU"  Germany
#    Alpha-3 code  Country
# 82        "DEU"  Germany
#    Alpha-3 code  Country
# 82        "DEU"  Germany
#    Alpha-3 code  Country
# 82        "DEU"  Germany
#    Alpha-3 code  Country
# 82        "DEU"  Germany
#    Alpha-3 code  Country
# 82        "DEU"  Germany
#    Alpha-3 code  Country
# 82        "DEU"  Germany
#    Alpha-3 code  Country
# 82        "DEU"  Germany
#    Alpha-3 code  Country
# 82        "DEU"  Germany
#    Alpha-3 code  Country
# 82        "DEU"  Germany
#    Alpha-3 code  Country
# 82        "DEU"  Germany
#    Alpha-3 code  Country
# 82        "DEU"  Germany
#    Alpha-3 code  Country
# 82        "DEU"  Germany
#    Alpha-3 code  Country
# 82        "DEU"  Germany
#    Alpha-3 code  Country
# 82        "DEU"  Germany
#    Alpha-3 code Country
# 85        "GRC"  Greece
#    Alpha-3 code Country
# 85        "GRC"  Greece
#    Alpha-3 code Country
# 85        "GRC"  Greece
#    Alpha-3 code Country
# 85        "GRC"  Greece
#    Alpha-3 code Country
# 85        "GRC"  Greece
#    Alpha-3 code Country
# 85        "GRC"  Greece
#    Alpha-3 code Country
# 85        "GRC"  Greece
#    Alpha-3 code Country
# 85        "GRC"  Greece
#    Alpha-3 code Country
# 85        "GRC"  Greece
#    Alpha-3 code Country
# 85        "GRC"  Greece
#    Alpha-3 code Country
# 85        "GRC"  Greece
#    Alpha-3 code Country
# 85        "GRC"  Greece
#    Alpha-3 code Country
# 85        "GRC"  Greece
#    Alpha-3 code Country
# 85        "GRC"  Greece
#     Alpha-3 code  Country
# 100        "HUN"  Hungary
#     Alpha-3 code  Country
# 100        "HUN"  Hungary
#     Alpha-3 code  Country
# 100        "HUN"  Hungary
#     Alpha-3 code  Country
# 100        "HUN"  Hungary
#     Alpha-3 code  Country
# 100        "HUN"  Hungary
#     Alpha-3 code  Country
# 100        "HUN"  Hungary
#     Alpha-3 code  Country
# 100        "HUN"  Hungary
#     Alpha-3 code  Country
# 100        "HUN"  Hungary
#     Alpha-3 code  Country
# 100        "HUN"  Hungary
#     Alpha-3 code  Country
# 100        "HUN"  Hungary
#     Alpha-3 code  Country
# 100        "HUN"  Hungary
#     Alpha-3 code  Country
# 100        "HUN"  Hungary
#     Alpha-3 code  Country
# 100        "HUN"  Hungary
#     Alpha-3 code  Country
# 100        "HUN"  Hungary
#     Alpha-3 code  Country
# 101        "ISL"  Iceland
#     Alpha-3 code  Country
# 101        "ISL"  Iceland
#     Alpha-3 code  Country
# 101        "ISL"  Iceland
#     Alpha-3 code  Country
# 101        "ISL"  Iceland
#     Alpha-3 code  Country
# 101        "ISL"  Iceland
#     Alpha-3 code  Country
# 101        "ISL"  Iceland
#     Alpha-3 code  Country
# 101        "ISL"  Iceland
#     Alpha-3 code  Country
# 101        "ISL"  Iceland
#     Alpha-3 code  Country
# 106        "IRL"  Ireland
#     Alpha-3 code  Country
# 106        "IRL"  Ireland
#     Alpha-3 code  Country
# 106        "IRL"  Ireland
#     Alpha-3 code  Country
# 106        "IRL"  Ireland
#     Alpha-3 code  Country
# 106        "IRL"  Ireland
#     Alpha-3 code  Country
# 106        "IRL"  Ireland
#     Alpha-3 code  Country
# 106        "IRL"  Ireland
#     Alpha-3 code  Country
# 106        "IRL"  Ireland
#     Alpha-3 code  Country
# 106        "IRL"  Ireland
#     Alpha-3 code  Country
# 106        "IRL"  Ireland
#     Alpha-3 code  Country
# 106        "IRL"  Ireland
#     Alpha-3 code  Country
# 106        "IRL"  Ireland
#     Alpha-3 code  Country
# 106        "IRL"  Ireland
#     Alpha-3 code  Country
# 106        "IRL"  Ireland
#     Alpha-3 code Country
# 109        "ITA"   Italy
#     Alpha-3 code Country
# 109        "ITA"   Italy
#     Alpha-3 code Country
# 109        "ITA"   Italy
#     Alpha-3 code Country
# 109        "ITA"   Italy
#     Alpha-3 code Country
# 109        "ITA"   Italy
#     Alpha-3 code Country
# 109        "ITA"   Italy
#     Alpha-3 code Country
# 109        "ITA"   Italy
#     Alpha-3 code Country
# 109        "ITA"   Italy
#     Alpha-3 code Country
# 109        "ITA"   Italy
#     Alpha-3 code Country
# 109        "ITA"   Italy
#     Alpha-3 code Country
# 109        "ITA"   Italy
#     Alpha-3 code Country
# 109        "ITA"   Italy
#     Alpha-3 code Country
# 109        "ITA"   Italy
#     Alpha-3 code Country
# 109        "ITA"   Italy
#     Alpha-3 code Country
# 109        "ITA"   Italy
#     Alpha-3 code Country
# 111        "JPN"   Japan
#     Alpha-3 code Country
# 111        "JPN"   Japan
#     Alpha-3 code Country
# 111        "JPN"   Japan
#     Alpha-3 code Country
# 111        "JPN"   Japan
#     Alpha-3 code Country
# 111        "JPN"   Japan
#     Alpha-3 code Country
# 111        "JPN"   Japan
#     Alpha-3 code Country
# 111        "JPN"   Japan
#     Alpha-3 code Country
# 111        "JPN"   Japan
#     Alpha-3 code Country
# 111        "JPN"   Japan
#     Alpha-3 code Country
# 111        "JPN"   Japan
#     Alpha-3 code Country
# 111        "JPN"   Japan
#     Alpha-3 code Country
# 111        "JPN"   Japan
#     Alpha-3 code Country
# 111        "JPN"   Japan
#     Alpha-3 code Country
# 111        "JPN"   Japan
#     Alpha-3 code Country
# 111        "JPN"   Japan
#     Alpha-3 code             Country
# 118        "KOR"  Korea, Republic of
# 119        "KOR"         South Korea
#     Alpha-3 code             Country
# 118        "KOR"  Korea, Republic of
# 119        "KOR"         South Korea
#     Alpha-3 code             Country
# 118        "KOR"  Korea, Republic of
# 119        "KOR"         South Korea
#     Alpha-3 code             Country
# 118        "KOR"  Korea, Republic of
# 119        "KOR"         South Korea
#     Alpha-3 code             Country
# 118        "KOR"  Korea, Republic of
# 119        "KOR"         South Korea
#     Alpha-3 code             Country
# 118        "KOR"  Korea, Republic of
# 119        "KOR"         South Korea
#     Alpha-3 code             Country
# 118        "KOR"  Korea, Republic of
# 119        "KOR"         South Korea
#     Alpha-3 code             Country
# 118        "KOR"  Korea, Republic of
# 119        "KOR"         South Korea
#     Alpha-3 code             Country
# 118        "KOR"  Korea, Republic of
# 119        "KOR"         South Korea
#     Alpha-3 code             Country
# 118        "KOR"  Korea, Republic of
# 119        "KOR"         South Korea
#     Alpha-3 code             Country
# 118        "KOR"  Korea, Republic of
# 119        "KOR"         South Korea
#     Alpha-3 code             Country
# 118        "KOR"  Korea, Republic of
# 119        "KOR"         South Korea
#     Alpha-3 code             Country
# 118        "KOR"  Korea, Republic of
# 119        "KOR"         South Korea
#     Alpha-3 code             Country
# 118        "KOR"  Korea, Republic of
# 119        "KOR"         South Korea
#     Alpha-3 code             Country
# 118        "KOR"  Korea, Republic of
# 119        "KOR"         South Korea
#     Alpha-3 code     Country
# 131        "LUX"  Luxembourg
#     Alpha-3 code     Country
# 131        "LUX"  Luxembourg
#     Alpha-3 code     Country
# 131        "LUX"  Luxembourg
#     Alpha-3 code     Country
# 131        "LUX"  Luxembourg
#     Alpha-3 code     Country
# 131        "LUX"  Luxembourg
#     Alpha-3 code     Country
# 131        "LUX"  Luxembourg
#     Alpha-3 code     Country
# 131        "LUX"  Luxembourg
#     Alpha-3 code     Country
# 131        "LUX"  Luxembourg
#     Alpha-3 code     Country
# 131        "LUX"  Luxembourg
#     Alpha-3 code     Country
# 131        "LUX"  Luxembourg
#     Alpha-3 code     Country
# 131        "LUX"  Luxembourg
#     Alpha-3 code Country
# 145        "MEX"  Mexico
#     Alpha-3 code Country
# 145        "MEX"  Mexico
#     Alpha-3 code Country
# 145        "MEX"  Mexico
#     Alpha-3 code Country
# 145        "MEX"  Mexico
#     Alpha-3 code Country
# 145        "MEX"  Mexico
#     Alpha-3 code Country
# 145        "MEX"  Mexico
#     Alpha-3 code Country
# 145        "MEX"  Mexico
#     Alpha-3 code Country
# 145        "MEX"  Mexico
#     Alpha-3 code Country
# 145        "MEX"  Mexico
#     Alpha-3 code Country
# 145        "MEX"  Mexico
#     Alpha-3 code Country
# 145        "MEX"  Mexico
#     Alpha-3 code Country
# 145        "MEX"  Mexico
#     Alpha-3 code Country
# 145        "MEX"  Mexico
#     Alpha-3 code Country
# 145        "MEX"  Mexico
#     Alpha-3 code Country
# 145        "MEX"  Mexico
#     Alpha-3 code      Country
# 159        "NLD"  Netherlands
#     Alpha-3 code      Country
# 159        "NLD"  Netherlands
#     Alpha-3 code      Country
# 159        "NLD"  Netherlands
#     Alpha-3 code      Country
# 159        "NLD"  Netherlands
#     Alpha-3 code      Country
# 159        "NLD"  Netherlands
#     Alpha-3 code      Country
# 159        "NLD"  Netherlands
#     Alpha-3 code      Country
# 159        "NLD"  Netherlands
#     Alpha-3 code      Country
# 159        "NLD"  Netherlands
#     Alpha-3 code      Country
# 159        "NLD"  Netherlands
#     Alpha-3 code      Country
# 159        "NLD"  Netherlands
#     Alpha-3 code      Country
# 159        "NLD"  Netherlands
#     Alpha-3 code      Country
# 159        "NLD"  Netherlands
#     Alpha-3 code      Country
# 159        "NLD"  Netherlands
#     Alpha-3 code      Country
# 159        "NLD"  Netherlands
#     Alpha-3 code      Country
# 162        "NZL"  New Zealand
#     Alpha-3 code      Country
# 162        "NZL"  New Zealand
#     Alpha-3 code      Country
# 162        "NZL"  New Zealand
#     Alpha-3 code      Country
# 162        "NZL"  New Zealand
#     Alpha-3 code      Country
# 162        "NZL"  New Zealand
#     Alpha-3 code      Country
# 162        "NZL"  New Zealand
#     Alpha-3 code      Country
# 162        "NZL"  New Zealand
#     Alpha-3 code      Country
# 162        "NZL"  New Zealand
#     Alpha-3 code      Country
# 162        "NZL"  New Zealand
#     Alpha-3 code      Country
# 162        "NZL"  New Zealand
#     Alpha-3 code      Country
# 162        "NZL"  New Zealand
#     Alpha-3 code      Country
# 162        "NZL"  New Zealand
#     Alpha-3 code      Country
# 162        "NZL"  New Zealand
#     Alpha-3 code      Country
# 162        "NZL"  New Zealand
#     Alpha-3 code Country
# 169        "NOR"  Norway
#     Alpha-3 code Country
# 169        "NOR"  Norway
#     Alpha-3 code Country
# 169        "NOR"  Norway
#     Alpha-3 code Country
# 169        "NOR"  Norway
#     Alpha-3 code Country
# 169        "NOR"  Norway
#     Alpha-3 code Country
# 169        "NOR"  Norway
#     Alpha-3 code Country
# 169        "NOR"  Norway
#     Alpha-3 code Country
# 169        "NOR"  Norway
#     Alpha-3 code Country
# 169        "NOR"  Norway
#     Alpha-3 code Country
# 169        "NOR"  Norway
#     Alpha-3 code Country
# 180        "POL"  Poland
#     Alpha-3 code Country
# 180        "POL"  Poland
#     Alpha-3 code Country
# 180        "POL"  Poland
#     Alpha-3 code Country
# 180        "POL"  Poland
#     Alpha-3 code Country
# 180        "POL"  Poland
#     Alpha-3 code Country
# 180        "POL"  Poland
#     Alpha-3 code Country
# 180        "POL"  Poland
#     Alpha-3 code Country
# 180        "POL"  Poland
#     Alpha-3 code Country
# 180        "POL"  Poland
#     Alpha-3 code Country
# 180        "POL"  Poland
#     Alpha-3 code Country
# 180        "POL"  Poland
#     Alpha-3 code Country
# 180        "POL"  Poland
#     Alpha-3 code Country
# 180        "POL"  Poland
#     Alpha-3 code Country
# 180        "POL"  Poland
#     Alpha-3 code Country
# 180        "POL"  Poland
#     Alpha-3 code   Country
# 181        "PRT"  Portugal
#     Alpha-3 code   Country
# 181        "PRT"  Portugal
#     Alpha-3 code   Country
# 181        "PRT"  Portugal
#     Alpha-3 code   Country
# 181        "PRT"  Portugal
#     Alpha-3 code   Country
# 181        "PRT"  Portugal
#     Alpha-3 code   Country
# 181        "PRT"  Portugal
#     Alpha-3 code   Country
# 181        "PRT"  Portugal
#     Alpha-3 code   Country
# 181        "PRT"  Portugal
#     Alpha-3 code   Country
# 181        "PRT"  Portugal
#     Alpha-3 code   Country
# 181        "PRT"  Portugal
#     Alpha-3 code   Country
# 181        "PRT"  Portugal
#     Alpha-3 code   Country
# 181        "PRT"  Portugal
#     Alpha-3 code   Country
# 181        "PRT"  Portugal
#     Alpha-3 code   Country
# 181        "PRT"  Portugal
#     Alpha-3 code   Country
# 205        "SVK"  Slovakia
#     Alpha-3 code   Country
# 205        "SVK"  Slovakia
#     Alpha-3 code   Country
# 205        "SVK"  Slovakia
#     Alpha-3 code   Country
# 205        "SVK"  Slovakia
#     Alpha-3 code   Country
# 205        "SVK"  Slovakia
#     Alpha-3 code   Country
# 205        "SVK"  Slovakia
#     Alpha-3 code   Country
# 205        "SVK"  Slovakia
#     Alpha-3 code   Country
# 205        "SVK"  Slovakia
#     Alpha-3 code   Country
# 205        "SVK"  Slovakia
#     Alpha-3 code   Country
# 205        "SVK"  Slovakia
#     Alpha-3 code   Country
# 205        "SVK"  Slovakia
#     Alpha-3 code   Country
# 205        "SVK"  Slovakia
#     Alpha-3 code Country
# 212        "ESP"   Spain
#     Alpha-3 code Country
# 212        "ESP"   Spain
#     Alpha-3 code Country
# 212        "ESP"   Spain
#     Alpha-3 code Country
# 212        "ESP"   Spain
#     Alpha-3 code Country
# 212        "ESP"   Spain
#     Alpha-3 code Country
# 212        "ESP"   Spain
#     Alpha-3 code Country
# 212        "ESP"   Spain
#     Alpha-3 code Country
# 212        "ESP"   Spain
#     Alpha-3 code Country
# 212        "ESP"   Spain
#     Alpha-3 code Country
# 212        "ESP"   Spain
#     Alpha-3 code Country
# 212        "ESP"   Spain
#     Alpha-3 code Country
# 212        "ESP"   Spain
#     Alpha-3 code Country
# 212        "ESP"   Spain
#     Alpha-3 code Country
# 212        "ESP"   Spain
#     Alpha-3 code Country
# 212        "ESP"   Spain
#     Alpha-3 code Country
# 218        "SWE"  Sweden
#     Alpha-3 code Country
# 218        "SWE"  Sweden
#     Alpha-3 code Country
# 218        "SWE"  Sweden
#     Alpha-3 code Country
# 218        "SWE"  Sweden
#     Alpha-3 code Country
# 218        "SWE"  Sweden
#     Alpha-3 code Country
# 218        "SWE"  Sweden
#     Alpha-3 code Country
# 218        "SWE"  Sweden
#     Alpha-3 code Country
# 218        "SWE"  Sweden
#     Alpha-3 code Country
# 218        "SWE"  Sweden
#     Alpha-3 code Country
# 218        "SWE"  Sweden
#     Alpha-3 code Country
# 218        "SWE"  Sweden
#     Alpha-3 code Country
# 218        "SWE"  Sweden
#     Alpha-3 code Country
# 218        "SWE"  Sweden
#     Alpha-3 code Country
# 218        "SWE"  Sweden
#     Alpha-3 code Country
# 218        "SWE"  Sweden
#     Alpha-3 code      Country
# 219        "CHE"  Switzerland
#     Alpha-3 code      Country
# 219        "CHE"  Switzerland
#     Alpha-3 code      Country
# 219        "CHE"  Switzerland
#     Alpha-3 code      Country
# 219        "CHE"  Switzerland
#     Alpha-3 code      Country
# 219        "CHE"  Switzerland
#     Alpha-3 code      Country
# 219        "CHE"  Switzerland
#     Alpha-3 code      Country
# 219        "CHE"  Switzerland
#     Alpha-3 code      Country
# 219        "CHE"  Switzerland
#     Alpha-3 code      Country
# 219        "CHE"  Switzerland
#     Alpha-3 code      Country
# 219        "CHE"  Switzerland
#     Alpha-3 code Country
# 232        "TUR"  Turkey
#     Alpha-3 code Country
# 232        "TUR"  Turkey
#     Alpha-3 code Country
# 232        "TUR"  Turkey
#     Alpha-3 code Country
# 232        "TUR"  Turkey
#     Alpha-3 code Country
# 232        "TUR"  Turkey
#     Alpha-3 code Country
# 232        "TUR"  Turkey
#     Alpha-3 code Country
# 232        "TUR"  Turkey
#     Alpha-3 code Country
# 232        "TUR"  Turkey
#     Alpha-3 code Country
# 232        "TUR"  Turkey
#     Alpha-3 code Country
# 232        "TUR"  Turkey
#     Alpha-3 code Country
# 232        "TUR"  Turkey
#     Alpha-3 code Country
# 232        "TUR"  Turkey
#     Alpha-3 code Country
# 232        "TUR"  Turkey
#     Alpha-3 code Country
# 232        "TUR"  Turkey
#     Alpha-3 code         Country
# 239        "GBR"  United Kingdom
#     Alpha-3 code         Country
# 239        "GBR"  United Kingdom
#     Alpha-3 code         Country
# 239        "GBR"  United Kingdom
#     Alpha-3 code         Country
# 239        "GBR"  United Kingdom
#     Alpha-3 code         Country
# 239        "GBR"  United Kingdom
#     Alpha-3 code         Country
# 239        "GBR"  United Kingdom
#     Alpha-3 code         Country
# 239        "GBR"  United Kingdom
#     Alpha-3 code         Country
# 239        "GBR"  United Kingdom
#     Alpha-3 code         Country
# 239        "GBR"  United Kingdom
#     Alpha-3 code         Country
# 239        "GBR"  United Kingdom
#     Alpha-3 code         Country
# 239        "GBR"  United Kingdom
#     Alpha-3 code         Country
# 239        "GBR"  United Kingdom
#     Alpha-3 code         Country
# 239        "GBR"  United Kingdom
#     Alpha-3 code         Country
# 239        "GBR"  United Kingdom
#     Alpha-3 code         Country
# 239        "GBR"  United Kingdom
#     Alpha-3 code        Country
# 240        "USA"  United States
#     Alpha-3 code        Country
# 240        "USA"  United States
#     Alpha-3 code        Country
# 240        "USA"  United States
#     Alpha-3 code        Country
# 240        "USA"  United States
#     Alpha-3 code        Country
# 240        "USA"  United States
#     Alpha-3 code        Country
# 240        "USA"  United States
#     Alpha-3 code        Country
# 240        "USA"  United States
#     Alpha-3 code        Country
# 240        "USA"  United States
#     Alpha-3 code        Country
# 240        "USA"  United States
#     Alpha-3 code        Country
# 240        "USA"  United States
#     Alpha-3 code        Country
# 240        "USA"  United States
#     Alpha-3 code        Country
# 240        "USA"  United States
#     Alpha-3 code        Country
# 240        "USA"  United States
#     Alpha-3 code        Country
# 240        "USA"  United States
#     Alpha-3 code        Country
# 240        "USA"  United States
#    Alpha-3 code Country
# 30        "BRA"  Brazil
#    Alpha-3 code Country
# 30        "BRA"  Brazil
#    Alpha-3 code Country
# 30        "BRA"  Brazil
#    Alpha-3 code Country
# 30        "BRA"  Brazil
#    Alpha-3 code Country
# 30        "BRA"  Brazil
#    Alpha-3 code Country
# 30        "BRA"  Brazil
#    Alpha-3 code Country
# 30        "BRA"  Brazil
#    Alpha-3 code Country
# 30        "BRA"  Brazil
#    Alpha-3 code Country
# 30        "BRA"  Brazil
#    Alpha-3 code Country
# 30        "BRA"  Brazil
#    Alpha-3 code Country
# 30        "BRA"  Brazil
#    Alpha-3 code Country
# 30        "BRA"  Brazil
#    Alpha-3 code Country
# 30        "BRA"  Brazil
#    Alpha-3 code Country
# 30        "BRA"  Brazil
#    Alpha-3 code Country
# 30        "BRA"  Brazil
#    Alpha-3 code Country
# 44        "CHL"   Chile
#    Alpha-3 code Country
# 44        "CHL"   Chile
#    Alpha-3 code Country
# 44        "CHL"   Chile
#    Alpha-3 code Country
# 44        "CHL"   Chile
#    Alpha-3 code Country
# 44        "CHL"   Chile
#    Alpha-3 code Country
# 44        "CHL"   Chile
#    Alpha-3 code Country
# 44        "CHL"   Chile
#    Alpha-3 code Country
# 44        "CHL"   Chile
#    Alpha-3 code Country
# 44        "CHL"   Chile
#    Alpha-3 code Country
# 44        "CHL"   Chile
#    Alpha-3 code Country
# 44        "CHL"   Chile
#    Alpha-3 code Country
# 44        "CHL"   Chile
#    Alpha-3 code Country
# 44        "CHL"   Chile
#    Alpha-3 code Country
# 44        "CHL"   Chile
#    Alpha-3 code Country
# 44        "CHL"   Chile
#    Alpha-3 code   Country
# 48        "COL"  Colombia
#    Alpha-3 code   Country
# 48        "COL"  Colombia
#    Alpha-3 code   Country
# 48        "COL"  Colombia
#    Alpha-3 code   Country
# 48        "COL"  Colombia
#    Alpha-3 code   Country
# 48        "COL"  Colombia
#    Alpha-3 code   Country
# 48        "COL"  Colombia
#    Alpha-3 code   Country
# 48        "COL"  Colombia
#    Alpha-3 code   Country
# 48        "COL"  Colombia
#    Alpha-3 code   Country
# 48        "COL"  Colombia
#    Alpha-3 code   Country
# 48        "COL"  Colombia
#    Alpha-3 code   Country
# 48        "COL"  Colombia
#    Alpha-3 code   Country
# 48        "COL"  Colombia
#    Alpha-3 code   Country
# 48        "COL"  Colombia
#    Alpha-3 code   Country
# 48        "COL"  Colombia
#    Alpha-3 code   Country
# 48        "COL"  Colombia
#    Alpha-3 code     Country
# 53        "CRI"  Costa Rica
#    Alpha-3 code     Country
# 53        "CRI"  Costa Rica
#    Alpha-3 code     Country
# 53        "CRI"  Costa Rica
#    Alpha-3 code     Country
# 53        "CRI"  Costa Rica
#    Alpha-3 code     Country
# 53        "CRI"  Costa Rica
#    Alpha-3 code     Country
# 53        "CRI"  Costa Rica
#    Alpha-3 code     Country
# 53        "CRI"  Costa Rica
#    Alpha-3 code     Country
# 53        "CRI"  Costa Rica
#    Alpha-3 code     Country
# 53        "CRI"  Costa Rica
#    Alpha-3 code     Country
# 53        "CRI"  Costa Rica
#    Alpha-3 code     Country
# 53        "CRI"  Costa Rica
#    Alpha-3 code     Country
# 53        "CRI"  Costa Rica
#    Alpha-3 code     Country
# 53        "CRI"  Costa Rica
#    Alpha-3 code     Country
# 53        "CRI"  Costa Rica
#    Alpha-3 code     Country
# 53        "CRI"  Costa Rica
#    Alpha-3 code  Country
# 69        "EST"  Estonia
#    Alpha-3 code  Country
# 69        "EST"  Estonia
#    Alpha-3 code  Country
# 69        "EST"  Estonia
#    Alpha-3 code  Country
# 69        "EST"  Estonia
#    Alpha-3 code  Country
# 69        "EST"  Estonia
#    Alpha-3 code  Country
# 69        "EST"  Estonia
#    Alpha-3 code  Country
# 69        "EST"  Estonia
#    Alpha-3 code  Country
# 69        "EST"  Estonia
#    Alpha-3 code  Country
# 69        "EST"  Estonia
#    Alpha-3 code  Country
# 69        "EST"  Estonia
#    Alpha-3 code  Country
# 69        "EST"  Estonia
#    Alpha-3 code  Country
# 69        "EST"  Estonia
#    Alpha-3 code  Country
# 69        "EST"  Estonia
#    Alpha-3 code  Country
# 69        "EST"  Estonia
#     Alpha-3 code Country
# 108        "ISR"  Israel
#     Alpha-3 code Country
# 108        "ISR"  Israel
#     Alpha-3 code Country
# 108        "ISR"  Israel
#     Alpha-3 code Country
# 108        "ISR"  Israel
#     Alpha-3 code Country
# 108        "ISR"  Israel
#     Alpha-3 code Country
# 108        "ISR"  Israel
#     Alpha-3 code Country
# 108        "ISR"  Israel
#     Alpha-3 code Country
# 108        "ISR"  Israel
#     Alpha-3 code Country
# 108        "ISR"  Israel
#     Alpha-3 code Country
# 108        "ISR"  Israel
#     Alpha-3 code Country
# 108        "ISR"  Israel
#     Alpha-3 code Country
# 108        "ISR"  Israel
#     Alpha-3 code Country
# 108        "ISR"  Israel
#     Alpha-3 code Country
# 108        "ISR"  Israel
#     Alpha-3 code Country
# 108        "ISR"  Israel
#     Alpha-3 code Country
# 123        "LVA"  Latvia
#     Alpha-3 code Country
# 123        "LVA"  Latvia
#     Alpha-3 code Country
# 123        "LVA"  Latvia
#     Alpha-3 code Country
# 123        "LVA"  Latvia
#     Alpha-3 code Country
# 123        "LVA"  Latvia
#     Alpha-3 code Country
# 123        "LVA"  Latvia
#     Alpha-3 code Country
# 123        "LVA"  Latvia
#     Alpha-3 code Country
# 123        "LVA"  Latvia
#     Alpha-3 code Country
# 123        "LVA"  Latvia
#     Alpha-3 code Country
# 123        "LVA"  Latvia
#     Alpha-3 code Country
# 123        "LVA"  Latvia
#     Alpha-3 code Country
# 123        "LVA"  Latvia
#     Alpha-3 code Country
# 123        "LVA"  Latvia
#     Alpha-3 code Country
# 123        "LVA"  Latvia
#     Alpha-3 code    Country
# 130        "LTU"  Lithuania
#     Alpha-3 code    Country
# 130        "LTU"  Lithuania
#     Alpha-3 code    Country
# 130        "LTU"  Lithuania
#     Alpha-3 code    Country
# 130        "LTU"  Lithuania
#     Alpha-3 code    Country
# 130        "LTU"  Lithuania
#     Alpha-3 code    Country
# 130        "LTU"  Lithuania
#     Alpha-3 code    Country
# 130        "LTU"  Lithuania
#     Alpha-3 code    Country
# 130        "LTU"  Lithuania
#     Alpha-3 code    Country
# 130        "LTU"  Lithuania
#     Alpha-3 code    Country
# 130        "LTU"  Lithuania
#     Alpha-3 code    Country
# 130        "LTU"  Lithuania
#     Alpha-3 code    Country
# 130        "LTU"  Lithuania
#     Alpha-3 code    Country
# 130        "LTU"  Lithuania
#     Alpha-3 code    Country
# 130        "LTU"  Lithuania
#     Alpha-3 code    Country
# 130        "LTU"  Lithuania
#     Alpha-3 code             Country
# 186        "RUS"  Russian Federation
# 187        "RUS"              Russia
#     Alpha-3 code             Country
# 186        "RUS"  Russian Federation
# 187        "RUS"              Russia
#     Alpha-3 code             Country
# 186        "RUS"  Russian Federation
# 187        "RUS"              Russia
#     Alpha-3 code             Country
# 186        "RUS"  Russian Federation
# 187        "RUS"              Russia
#     Alpha-3 code             Country
# 186        "RUS"  Russian Federation
# 187        "RUS"              Russia
#     Alpha-3 code             Country
# 186        "RUS"  Russian Federation
# 187        "RUS"              Russia
#     Alpha-3 code             Country
# 186        "RUS"  Russian Federation
# 187        "RUS"              Russia
#     Alpha-3 code             Country
# 186        "RUS"  Russian Federation
# 187        "RUS"              Russia
#     Alpha-3 code             Country
# 186        "RUS"  Russian Federation
# 187        "RUS"              Russia
#     Alpha-3 code             Country
# 186        "RUS"  Russian Federation
# 187        "RUS"              Russia
#     Alpha-3 code             Country
# 186        "RUS"  Russian Federation
# 187        "RUS"              Russia
#     Alpha-3 code             Country
# 186        "RUS"  Russian Federation
# 187        "RUS"              Russia
#     Alpha-3 code             Country
# 186        "RUS"  Russian Federation
# 187        "RUS"              Russia
#     Alpha-3 code             Country
# 186        "RUS"  Russian Federation
# 187        "RUS"              Russia
#     Alpha-3 code             Country
# 186        "RUS"  Russian Federation
# 187        "RUS"              Russia
#     Alpha-3 code   Country
# 206        "SVN"  Slovenia
#     Alpha-3 code   Country
# 206        "SVN"  Slovenia
#     Alpha-3 code   Country
# 206        "SVN"  Slovenia
#     Alpha-3 code   Country
# 206        "SVN"  Slovenia
#     Alpha-3 code   Country
# 206        "SVN"  Slovenia
#     Alpha-3 code   Country
# 206        "SVN"  Slovenia
#     Alpha-3 code   Country
# 206        "SVN"  Slovenia
#     Alpha-3 code   Country
# 206        "SVN"  Slovenia
#     Alpha-3 code   Country
# 206        "SVN"  Slovenia
#     Alpha-3 code   Country
# 206        "SVN"  Slovenia
#     Alpha-3 code   Country
# 206        "SVN"  Slovenia
#     Alpha-3 code   Country
# 206        "SVN"  Slovenia
#     Alpha-3 code   Country
# 206        "SVN"  Slovenia
#     Alpha-3 code       Country
# 209        "ZAF"  South Africa
#     Alpha-3 code       Country
# 209        "ZAF"  South Africa
#     Alpha-3 code       Country
# 209        "ZAF"  South Africa
#     Alpha-3 code       Country
# 209        "ZAF"  South Africa
#     Alpha-3 code       Country
# 209        "ZAF"  South Africa
#     Alpha-3 code       Country
# 209        "ZAF"  South Africa
#     Alpha-3 code       Country
# 209        "ZAF"  South Africa
#     Alpha-3 code       Country
# 209        "ZAF"  South Africa
#     Alpha-3 code       Country
# 209        "ZAF"  South Africa
#     Alpha-3 code       Country
# 209        "ZAF"  South Africa
#     Alpha-3 code       Country
# 209        "ZAF"  South Africa
#     Alpha-3 code       Country
# 209        "ZAF"  South Africa
#     Alpha-3 code       Country
# 209        "ZAF"  South Africa
#     Alpha-3 code       Country
# 209        "ZAF"  South Africa
#     Alpha-3 code       Country
# 209        "ZAF"  South Africa
