# %%
# Imports

import pandas as pd

# %% [markdown]
# ## 1. Load and Clean Data
#
# In the first step we need to load and clean our data

# %%
vax_rates = pd.read_csv('COVID-19_vaccination_rates.csv') 
vax_rates = vax_rates.loc[(vax_rates["date"]=="2021-10-25")]
vax_rates = vax_rates[["location","people_fully_vaccinated_per_hundred"]]
vax_rates.rename(columns={'location': 'Country Name'}, inplace=True)
vax_rates = vax_rates.loc[(vax_rates["people_fully_vaccinated_per_hundred"]==vax_rates["people_fully_vaccinated_per_hundred"])]
vax_rates
# Out:
#             Country Name  people_fully_vaccinated_per_hundred
# 568               Africa                                 5.53
# 901              Albania                                30.57
# 2713           Argentina                                55.56
# 3219               Aruba                                71.37
# 3578                Asia                                41.54
# ...                  ...                                  ...
# 65140            Vietnam                                22.23
# 65472              Wales                                70.69
# 65732  Wallis and Futuna                                49.25
# 66097              World                                37.62
# 66838           Zimbabwe                                16.88
#
# [122 rows x 2 columns]

# %%
# Change gov_trst from Country code to country name
codes = pd.read_csv('country_codes.csv')

lookup_table = codes[['Alpha-3 code','Country']]

# Lookup table to dict
c_map = {}
for i, t in lookup_table.iterrows():
    key = t[0][2:5]
    val = t[1]
    
    c_map[key] = val
    
trust_in_gov = pd.read_csv('trust_in_government.csv') 
    
# enhance government trust df
trust_in_gov = trust_in_gov.assign(country=trust_in_gov['LOCATION'].map(c_map))
 
trust_in_gov = trust_in_gov.loc[(trust_in_gov["TIME"]==2019)][["country","Value"]]
trust_in_gov.rename(columns={"Value": "trust_in_government_2019"}, inplace=True)
trust_in_gov.rename(columns={"country": "Country Name"}, inplace=True)
trust_in_gov
# Out:
#        Country Name  trust_in_government_2019
# 12        Australia                 46.870001
# 26          Austria                 51.233826
# 40          Belgium                 32.790115
# 55           Canada                 54.928097
# 83          Denmark                 63.299903
# 96          Finland                 63.918815
# 111          France                 38.184924
# 126         Germany                 56.846043
# 140          Greece                 39.642462
# 154         Hungary                 48.393419
# 162         Iceland                 52.137706
# 176         Ireland                 58.121598
# 191           Italy                 22.192586
# 206           Japan                 41.121365
# 221     South Korea                 37.675759
# 233      Luxembourg                 78.017101
# 247          Mexico                 49.523116
# 261     Netherlands                 61.657224
# 275     New Zealand                 67.520084
# 285          Norway                 59.798701
# 300          Poland                 49.798603
# 314        Portugal                 43.560500
# 326        Slovakia                 23.097283
# 341           Spain                 36.778586
# 356          Sweden                 51.328175
# 366     Switzerland                 80.661271
# 380          Turkey                 56.126091
# 395  United Kingdom                 34.082886
# 410   United States                 36.277444
# 425          Brazil                 34.085009
# 440           Chile                 15.252345
# 455        Colombia                 32.798110
# 470      Costa Rica                 28.302385
# 484         Estonia                 40.330654
# 499          Israel                 49.566691
# 513          Latvia                 23.940767
# 528       Lithuania                 40.724846
# 543          Russia                 43.696384
# 556        Slovenia                 39.715071
# 571    South Africa                 49.590632

# %%
gdp = pd.read_csv('gdp_per_capita.csv') 
gdp = gdp[["Country Name","2020"]]
gdp.rename(columns={'2020': 'gdp_per_capita_2020'}, inplace=True)
gdp = gdp.loc[(gdp["gdp_per_capita_2020"]==gdp["gdp_per_capita_2020"])]
gdp = gdp.set_index('Country Name')
gdp
# Out:
#                              gdp_per_capita_2020
# Country Name
# Africa Eastern and Southern          3677.111255
# Afghanistan                          2077.874554
# Africa Western and Central           4240.534782
# Angola                               6443.032680
# Albania                             13899.933981
# ...                                          ...
# Samoa                                6766.228447
# Kosovo                              11383.404733
# South Africa                        13355.598709
# Zambia                               3456.322534
# Zimbabwe                             3536.034132
#
# [237 rows x 1 columns]

# %%
secondary_edu = pd.read_csv('secondary_education.csv')  
secondary_edu = secondary_edu.loc[(secondary_edu["TIME"]==2019)].loc[(secondary_edu["SUBJECT"]=="UPPSRY")][["LOCATION","Value"]]
secondary_edu.rename(columns={"Value": "secondary_education_2019"}, inplace=True)

# Lookup table to dict
c_map = {}
for i, t in lookup_table.iterrows():
    key = t[0][2:5]
    val = t[1]
    
    c_map[key] = val
        
# enhance government trust df
secondary_edu = secondary_edu.assign(country=secondary_edu['LOCATION'].map(c_map))
secondary_edu = secondary_edu[['country', 'secondary_education_2019']]
secondary_edu.rename(columns={"country": "Country Name"}, inplace=True)

secondary_edu = secondary_edu.dropna()
secondary_edu
# Out:
#         Country Name  secondary_education_2019
# 9            Austria                    77.636
# 33           Belgium                    77.047
# 50            Canada                    84.317
# 79    Czech Republic                    80.510
# 104          Denmark                    81.629
# 137          Finland                    84.907
# 164          Germany                    73.092
# 180           Greece                    91.409
# 203          Hungary                    77.257
# 232          Iceland                    80.011
# 266            Italy                    89.629
# 276      South Korea                    95.814
# 297       Luxembourg                    72.229
# 330           Mexico                    66.332
# 360      Netherlands                    82.851
# 387      New Zealand                    85.911
# 420           Norway                    83.578
# 453           Poland                    83.227
# 486         Portugal                    79.362
# 519         Slovakia                    76.938
# 552            Spain                    74.744
# 585           Sweden                    70.380
# 613      Switzerland                    83.669
# 636           Turkey                    76.235
# 662   United Kingdom                    65.608
# 681    United States                    86.606
# 709           Brazil                    65.083
# 732            Chile                    90.132
# 759         Colombia                    77.038
# 772          Estonia                    80.195
# 789           Israel                    89.991
# 821           Latvia                    83.690
# 847         Slovenia                    90.889
# 1442      Costa Rica                    53.251
# 1463       Lithuania                    84.818

# %%
tert_edu = pd.read_csv('tertiary_education.csv')[["LOCATION","SUBJECT", "TIME", "Value"]]
tert_edu = tert_edu.loc[(tert_edu["TIME"]==2019)].loc[(tert_edu["SUBJECT"]=="BACHR_MEN")|(tert_edu["SUBJECT"]=="BACHR_WOMEN")]
tert_edu.rename(columns={"Value": "tertiary_education_2019"}, inplace=True)

tert_edu = tert_edu.pivot(index="LOCATION", columns="SUBJECT", values="tertiary_education_2019")
tert_edu['tertiary_education_2019'] = tert_edu["BACHR_MEN"] + tert_edu['BACHR_WOMEN']
tert_edu = tert_edu["tertiary_education_2019"].to_frame()
tert_edu = tert_edu.reset_index() 

# Lookup table to dict
c_map = {}
for i, t in lookup_table.iterrows():
    key = t[0][2:5]
    val = t[1]
    
    c_map[key] = val
        
# enhance government trust df
tert_edu = tert_edu.assign(country=tert_edu['LOCATION'].map(c_map))
tert_edu.rename(columns={"country": "Country Name"}, inplace=True)

tert_edu = tert_edu[['Country Name', 'tertiary_education_2019']]
tert_edu
# Out:
#       Country Name  tertiary_education_2019
# 0        Australia                   69.343
# 1          Austria                   37.418
# 2          Belgium                   80.736
# 3      Switzerland                   72.556
# 4            Chile                   52.185
# 5   Czech Republic                   50.212
# 6          Germany                   64.156
# 7          Denmark                   81.471
# 8            Spain                   63.931
# 9          Estonia                   54.380
# 10         Finland                   72.916
# 11  United Kingdom                   75.625
# 12          Greece                   75.157
# 13         Hungary                   37.610
# 14         Iceland                   64.937
# 15           Italy                   59.015
# 16       Lithuania                   91.839
# 17      Luxembourg                   11.467
# 18          Latvia                   53.538
# 19     Netherlands                   77.671
# 20          Norway                   75.057
# 21     New Zealand                   61.803
# 22             NaN                   61.747
# 23        Portugal                   67.364
# 24        Slovakia                   50.255
# 25        Slovenia                   70.610
# 26          Sweden                   35.828
# 27          Turkey                   60.084

# %%
cov_data = pd.read_csv('./worldwide_covid_data.csv')
cov_deaths = cov_data.rename(columns={'Country':'location'})[['location','Deaths/1M population']]
cov_deaths.rename(columns={"location": "Country Name"}, inplace=True)

cov_deaths
# Out:
#     Country Name  Deaths/1M population
# 0    Afghanistan                   182
# 1        Albania                  1034
# 2        Algeria                   133
# 3        Andorra                  1679
# 4         Angola                    50
# ..           ...                   ...
# 191    Venezuela                   176
# 192      Vietnam                   230
# 193        Yemen                    62
# 194       Zambia                   192
# 195     Zimbabwe                   310
#
# [196 rows x 2 columns]

# %%
betterlife = pd.read_csv('./betterlifeindex_2019.csv')

health = betterlife 
health.rename(columns={"Country": "Country Name"}, inplace=True)
health = health[["LOCATION", "Country Name","Indicator", "Value"]].loc[(health["Inequality"]=="Total")]
health = health.loc[(health["Indicator"]=="Self-reported health")][["Country Name", "Value"]]
health.rename(columns={"Value": "Self-reported_health_2019"}, inplace=True)
health
# Out:
#          Country Name  Self-reported_health_2019
# 1636        Australia                       85.0
# 1637          Austria                       70.0
# 1638          Belgium                       74.0
# 1639           Canada                       88.0
# 1640   Czech Republic                       60.0
# 1641          Denmark                       71.0
# 1642          Finland                       70.0
# 1643           France                       66.0
# 1644          Germany                       65.0
# 1645           Greece                       74.0
# 1646          Hungary                       60.0
# 1647          Iceland                       76.0
# 1648          Ireland                       83.0
# 1649            Italy                       71.0
# 1650            Japan                       36.0
# 1651            Korea                       33.0
# 1652       Luxembourg                       69.0
# 1653           Mexico                       66.0
# 1654      Netherlands                       76.0
# 1655      New Zealand                       88.0
# 1656           Norway                       77.0
# 1657           Poland                       58.0
# 1658         Portugal                       48.0
# 1659  Slovak Republic                       66.0
# 1660            Spain                       72.0
# 1661           Sweden                       75.0
# 1662      Switzerland                       78.0
# 1663           Turkey                       69.0
# 1664   United Kingdom                       69.0
# 1665    United States                       88.0
# 1666            Chile                       57.0
# 1667          Estonia                       53.0
# 1668           Israel                       84.0
# 1669           Latvia                       47.0
# 1670           Russia                       43.0
# 1671         Slovenia                       64.0
# 1672     OECD - Total                       69.0
# 2344        Lithuania                       43.0

# %%
life_exp = betterlife.loc[(betterlife["Indicator"]=="Life expectancy")][["Country Name", "LOCATION", "Value"]]
life_exp.rename(columns={"Value": "Life_expectancy_2019"}, inplace=True)
#life_exp = life_exp.set_index('Country Name')
life_exp = life_exp[['Life_expectancy_2019', 'Country Name']]
life_exp
# Out:
#       Life_expectancy_2019    Country Name
# 1519                  82.5       Australia
# 1520                  81.7         Austria
# 1521                  81.5         Belgium
# 1522                  81.9          Canada
# 1523                  79.1  Czech Republic
# ...                    ...             ...
# 2339                  74.8       Lithuania
# 2340                  73.1        Colombia
# 2341                  69.5       Lithuania
# 2342                  79.4        Colombia
# 2343                  80.1       Lithuania
#
# [123 rows x 2 columns]

# %%
work = betterlife.loc[(betterlife["Indicator"]=="Employees working very long hours")][["Country Name", "LOCATION", "Value"]]
work.rename(columns={"Value": "Employees_working_hours_2019"}, inplace=True)
work = work[['Country Name','Employees_working_hours_2019']]
work
# Out:
#         Country Name  Employees_working_hours_2019
# 2090       Australia                         13.04
# 2091         Austria                          6.66
# 2092         Belgium                          4.75
# 2093          Canada                          3.69
# 2094  Czech Republic                          5.65
# ...              ...                           ...
# 2364       Lithuania                          0.54
# 2365        Colombia                         32.09
# 2366       Lithuania                          0.67
# 2367        Colombia                         19.37
# 2368       Lithuania                          0.43
#
# [117 rows x 2 columns]

# %%
unemp = pd.read_csv('unemployment_rate.csv') 
unemp = unemp[["Country Name","2020"]] # select and reduce
unemp.rename(columns={"2020": "unemployment_2020"}, inplace=True)
unemp = unemp.loc[(unemp["unemployment_2020"]==unemp["unemployment_2020"])]
unemp
# Out:
#                     Country Name  unemployment_2020
# 1    Africa Eastern and Southern           6.814177
# 2                    Afghanistan          11.730000
# 3     Africa Western and Central           6.300105
# 4                         Angola           7.700000
# 5                        Albania          11.700000
# ..                           ...                ...
# 260                        Samoa           8.870000
# 262                  Yemen, Rep.          13.420000
# 263                 South Africa          28.740000
# 264                       Zambia          12.170000
# 265                     Zimbabwe           5.730000
#
# [235 rows x 2 columns]

# %%
## 2. analyse vaccination rate with each of the other factors

    In the second step we analyse the correlation and the scatter plot of each factor with the vaccination rate
# Out:
#   File "/tmp/ipykernel_5667/3253429324.py", line 3
#     In the second step we analyse the correlation and the scatter plot of each factor with the vaccination rate
#     ^
# IndentationError: unexpected indent

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#### TRUST IN GOVERNMENT ######


data = pd.merge(trust_in_gov, vax_rates, on=["Country Name"])
data
# Out:
#       Country Name  trust_in_government_2019  \
# 0        Australia                 46.870001
# 1          Austria                 51.233826
# 2          Belgium                 32.790115
# 3           Canada                 54.928097
# 4          Denmark                 63.299903
# 5          Finland                 63.918815
# 6           France                 38.184924
# 7          Germany                 56.846043
# 8           Greece                 39.642462
# 9          Hungary                 48.393419
# 10         Ireland                 58.121598
# 11           Italy                 22.192586
# 12           Japan                 41.121365
# 13     South Korea                 37.675759
# 14          Mexico                 49.523116
# 15     New Zealand                 67.520084
# 16          Norway                 59.798701
# 17          Poland                 49.798603
# 18        Portugal                 43.560500
# 19        Slovakia                 23.097283
# 20           Spain                 36.778586
# 21     Switzerland                 80.661271
# 22          Turkey                 56.126091
# 23  United Kingdom                 34.082886
# 24   United States                 36.277444
# 25          Brazil                 34.085009
# 26           Chile                 15.252345
# 27        Colombia                 32.798110
# 28         Estonia                 40.330654
# 29          Israel                 49.566691
# 30          Latvia                 23.940767
# 31       Lithuania                 40.724846
# 32        Slovenia                 39.715071
# 33    South Africa                 49.590632
#
#     people_fully_vaccinated_per_hundred
# 0                                 61.01
# 1                                 62.03
# 2                                 73.63
# 3                                 73.73
# 4                                 75.72
# 5                                 68.51
# 6                                 67.70
# 7                                 65.77
# 8                                 61.20
# 9                                 59.39
# 10                                75.23
# 11                                70.92
# 12                                70.45
# 13                                71.12
# 14                                41.34
# 15                                58.40
# 16                                68.28
# 17                                52.51
# 18                                87.19
# 19                                42.17
# 20                                79.69
# 21                                62.92
# 22                                56.70
# 23                                66.83
# 24                                57.60
# 25                                52.13
# 26                                76.72
# 27                                40.42
# 28                                56.70
# 29                                61.64
# 30                                52.64
# 31                                63.67
# 32                                53.50
# 33                                19.48

# %%
data
corrmat = data.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
g=sns.heatmap(data[['trust_in_government_2019', 'people_fully_vaccinated_per_hundred']].corr(),annot=True,cmap="RdYlGn")

# %%
plt.scatter(data['trust_in_government_2019'], data['people_fully_vaccinated_per_hundred'])
plt.xlabel('trust_in_government_2019')
plt.ylabel('people_fully_vaccinated_per_hundred')
plt.show()

# %%
#### GDP ######


data = pd.merge(gdp, vax_rates, on=["Country Name"])
data
# Out:
#     Country Name  gdp_per_capita_2020  people_fully_vaccinated_per_hundred
# 0        Albania         13899.933981                                30.57
# 1      Argentina         20762.991679                                55.56
# 2      Australia         52397.387048                                61.01
# 3        Austria         55648.874565                                62.03
# 4     Azerbaijan         14474.313361                                42.29
# ..           ...                  ...                                  ...
# 87       Vanuatu          3009.733927                                 9.72
# 88         World         17082.787590                                37.62
# 89         Samoa          6766.228447                                39.27
# 90  South Africa         13355.598709                                19.48
# 91      Zimbabwe          3536.034132                                16.88
#
# [92 rows x 3 columns]

# %%
data
corrmat = data.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
g=sns.heatmap(data[['gdp_per_capita_2020', 'people_fully_vaccinated_per_hundred']].corr(),annot=True,cmap="RdYlGn")

# %%
plt.scatter(data['gdp_per_capita_2020'], data['people_fully_vaccinated_per_hundred'])
plt.xlabel('gdp_per_capita_2020')
plt.ylabel('people_fully_vaccinated_per_hundred')
plt.show()

# %%
#### secondary education ######


data = pd.merge(secondary_edu, vax_rates, on=["Country Name"])
data
# Out:
#       Country Name  secondary_education_2019  \
# 0          Austria                    77.636
# 1          Belgium                    77.047
# 2           Canada                    84.317
# 3          Denmark                    81.629
# 4          Finland                    84.907
# 5          Germany                    73.092
# 6           Greece                    91.409
# 7          Hungary                    77.257
# 8            Italy                    89.629
# 9      South Korea                    95.814
# 10          Mexico                    66.332
# 11     New Zealand                    85.911
# 12          Norway                    83.578
# 13          Poland                    83.227
# 14        Portugal                    79.362
# 15        Slovakia                    76.938
# 16           Spain                    74.744
# 17     Switzerland                    83.669
# 18          Turkey                    76.235
# 19  United Kingdom                    65.608
# 20   United States                    86.606
# 21          Brazil                    65.083
# 22           Chile                    90.132
# 23        Colombia                    77.038
# 24         Estonia                    80.195
# 25          Israel                    89.991
# 26          Latvia                    83.690
# 27        Slovenia                    90.889
# 28       Lithuania                    84.818
#
#     people_fully_vaccinated_per_hundred
# 0                                 62.03
# 1                                 73.63
# 2                                 73.73
# 3                                 75.72
# 4                                 68.51
# 5                                 65.77
# 6                                 61.20
# 7                                 59.39
# 8                                 70.92
# 9                                 71.12
# 10                                41.34
# 11                                58.40
# 12                                68.28
# 13                                52.51
# 14                                87.19
# 15                                42.17
# 16                                79.69
# 17                                62.92
# 18                                56.70
# 19                                66.83
# 20                                57.60
# 21                                52.13
# 22                                76.72
# 23                                40.42
# 24                                56.70
# 25                                61.64
# 26                                52.64
# 27                                53.50
# 28                                63.67

# %%
data
corrmat = data.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
g=sns.heatmap(data[['secondary_education_2019', 'people_fully_vaccinated_per_hundred']].corr(),annot=True,cmap="RdYlGn")

# %%
plt.scatter(data['secondary_education_2019'], data['people_fully_vaccinated_per_hundred'])
plt.xlabel('secondary_education_2019')
plt.ylabel('people_fully_vaccinated_per_hundred')
plt.show()

# %%
#### tertiary education ######


data = pd.merge(tert_edu, vax_rates, on=["Country Name"])
data
# Out:
#       Country Name  tertiary_education_2019  \
# 0        Australia                   69.343
# 1          Austria                   37.418
# 2          Belgium                   80.736
# 3      Switzerland                   72.556
# 4            Chile                   52.185
# 5          Germany                   64.156
# 6          Denmark                   81.471
# 7            Spain                   63.931
# 8          Estonia                   54.380
# 9          Finland                   72.916
# 10  United Kingdom                   75.625
# 11          Greece                   75.157
# 12         Hungary                   37.610
# 13           Italy                   59.015
# 14       Lithuania                   91.839
# 15          Latvia                   53.538
# 16          Norway                   75.057
# 17     New Zealand                   61.803
# 18        Portugal                   67.364
# 19        Slovakia                   50.255
# 20        Slovenia                   70.610
# 21          Turkey                   60.084
#
#     people_fully_vaccinated_per_hundred
# 0                                 61.01
# 1                                 62.03
# 2                                 73.63
# 3                                 62.92
# 4                                 76.72
# 5                                 65.77
# 6                                 75.72
# 7                                 79.69
# 8                                 56.70
# 9                                 68.51
# 10                                66.83
# 11                                61.20
# 12                                59.39
# 13                                70.92
# 14                                63.67
# 15                                52.64
# 16                                68.28
# 17                                58.40
# 18                                87.19
# 19                                42.17
# 20                                53.50
# 21                                56.70

# %%
corrmat = data.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
g=sns.heatmap(data[['tertiary_education_2019', 'people_fully_vaccinated_per_hundred']].corr(),annot=True,cmap="RdYlGn")

# %%
plt.scatter(data['tertiary_education_2019'], data['people_fully_vaccinated_per_hundred'])
plt.xlabel('tertiary_education_2019')
plt.ylabel('people_fully_vaccinated_per_hundred')
plt.show()

# %%
#### COVID deaths ######


data = pd.merge(cov_deaths, vax_rates, on=["Country Name"])
data
# Out:
#    Country Name  Deaths/1M population  people_fully_vaccinated_per_hundred
# 0       Albania                  1034                                30.57
# 1     Argentina                  2539                                55.56
# 2         Aruba                  1602                                71.37
# 3     Australia                    71                                61.01
# 4       Austria                  1273                                62.03
# ..          ...                   ...                                  ...
# 85       Turkey                   847                                56.70
# 86      Ukraine                  1692                                16.29
# 87      Uruguay                  1746                                75.40
# 88      Vietnam                   230                                22.23
# 89     Zimbabwe                   310                                16.88
#
# [90 rows x 3 columns]

# %%
corrmat = data.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
g=sns.heatmap(data[['Deaths/1M population', 'people_fully_vaccinated_per_hundred']].corr(),annot=True,cmap="RdYlGn")

# %%
plt.scatter(data['Deaths/1M population'], data['people_fully_vaccinated_per_hundred'])
plt.xlabel('Deaths/1M population')
plt.ylabel('people_fully_vaccinated_per_hundred')
plt.show()

# %%
#### Self reported health ######


data = pd.merge(health, vax_rates, on=["Country Name"])
data
# Out:
#       Country Name  Self-reported_health_2019  \
# 0        Australia                       85.0
# 1          Austria                       70.0
# 2          Belgium                       74.0
# 3           Canada                       88.0
# 4          Denmark                       71.0
# 5          Finland                       70.0
# 6           France                       66.0
# 7          Germany                       65.0
# 8           Greece                       74.0
# 9          Hungary                       60.0
# 10         Ireland                       83.0
# 11           Italy                       71.0
# 12           Japan                       36.0
# 13          Mexico                       66.0
# 14     New Zealand                       88.0
# 15          Norway                       77.0
# 16          Poland                       58.0
# 17        Portugal                       48.0
# 18           Spain                       72.0
# 19     Switzerland                       78.0
# 20          Turkey                       69.0
# 21  United Kingdom                       69.0
# 22   United States                       88.0
# 23           Chile                       57.0
# 24         Estonia                       53.0
# 25          Israel                       84.0
# 26          Latvia                       47.0
# 27        Slovenia                       64.0
# 28       Lithuania                       43.0
#
#     people_fully_vaccinated_per_hundred
# 0                                 61.01
# 1                                 62.03
# 2                                 73.63
# 3                                 73.73
# 4                                 75.72
# 5                                 68.51
# 6                                 67.70
# 7                                 65.77
# 8                                 61.20
# 9                                 59.39
# 10                                75.23
# 11                                70.92
# 12                                70.45
# 13                                41.34
# 14                                58.40
# 15                                68.28
# 16                                52.51
# 17                                87.19
# 18                                79.69
# 19                                62.92
# 20                                56.70
# 21                                66.83
# 22                                57.60
# 23                                76.72
# 24                                56.70
# 25                                61.64
# 26                                52.64
# 27                                53.50
# 28                                63.67

# %%
corrmat = data.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
g=sns.heatmap(data[['Self-reported_health_2019', 'people_fully_vaccinated_per_hundred']].corr(),annot=True,cmap="RdYlGn")

# %%
plt.scatter(data['Self-reported_health_2019'], data['people_fully_vaccinated_per_hundred'])
plt.xlabel('Self-reported_health_2019')
plt.ylabel('people_fully_vaccinated_per_hundred')
plt.show()

# %%
#### life expectancy ######


data = pd.merge(life_exp, vax_rates, on=["Country Name"])
data
# Out:
#     Life_expectancy_2019 Country Name  people_fully_vaccinated_per_hundred
# 0                   82.5    Australia                                61.01
# 1                   80.4    Australia                                61.01
# 2                   84.6    Australia                                61.01
# 3                   81.7      Austria                                62.03
# 4                   79.3      Austria                                62.03
# ..                   ...          ...                                  ...
# 91                  73.1     Colombia                                40.42
# 92                  79.4     Colombia                                40.42
# 93                  74.8    Lithuania                                63.67
# 94                  69.5    Lithuania                                63.67
# 95                  80.1    Lithuania                                63.67
#
# [96 rows x 3 columns]

# %%
corrmat = data.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
g=sns.heatmap(data[['Life_expectancy_2019', 'people_fully_vaccinated_per_hundred']].corr(),annot=True,cmap="RdYlGn")

# %%
plt.scatter(data['Life_expectancy_2019'], data['people_fully_vaccinated_per_hundred'])
plt.xlabel('Life_expectancy_2019')
plt.ylabel('people_fully_vaccinated_per_hundred')
plt.show()

# %%
#### very long working hours ######

data = pd.merge(work, vax_rates, on=["Country Name"])
data
# Out:
#    Country Name  Employees_working_hours_2019  \
# 0     Australia                         13.04
# 1     Australia                         19.17
# 2     Australia                          6.31
# 3       Austria                          6.66
# 4       Austria                         10.01
# ..          ...                           ...
# 88     Colombia                         32.09
# 89     Colombia                         19.37
# 90    Lithuania                          0.54
# 91    Lithuania                          0.67
# 92    Lithuania                          0.43
#
#     people_fully_vaccinated_per_hundred
# 0                                 61.01
# 1                                 61.01
# 2                                 61.01
# 3                                 62.03
# 4                                 62.03
# ..                                  ...
# 88                                40.42
# 89                                40.42
# 90                                63.67
# 91                                63.67
# 92                                63.67
#
# [93 rows x 3 columns]

# %%
corrmat = data.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
g=sns.heatmap(data[['Employees_working_hours_2019', 'people_fully_vaccinated_per_hundred']].corr(),annot=True,cmap="RdYlGn")

# %%
plt.scatter(data['Employees_working_hours_2019'], data['people_fully_vaccinated_per_hundred'])
plt.xlabel('Employees_working_hours_2019')
plt.ylabel('people_fully_vaccinated_per_hundred')
plt.show()

# %%
#### unemployment ######

data = pd.merge(unemp, vax_rates, on=["Country Name"])
data
# Out:
#     Country Name  unemployment_2020  people_fully_vaccinated_per_hundred
# 0        Albania          11.700000                                30.57
# 1      Argentina          11.670000                                55.56
# 2      Australia           6.610000                                61.01
# 3        Austria           5.770000                                62.03
# 4     Azerbaijan           6.270000                                42.29
# ..           ...                ...                                  ...
# 88       Vanuatu           1.950000                                 9.72
# 89         World           6.471281                                37.62
# 90         Samoa           8.870000                                39.27
# 91  South Africa          28.740000                                19.48
# 92      Zimbabwe           5.730000                                16.88
#
# [93 rows x 3 columns]

# %%
corrmat = data.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
g=sns.heatmap(data[['unemployment_2020', 'people_fully_vaccinated_per_hundred']].corr(),annot=True,cmap="RdYlGn")

# %%
plt.scatter(data['unemployment_2020'], data['people_fully_vaccinated_per_hundred'])
plt.xlabel('unemployment_2020')
plt.ylabel('people_fully_vaccinated_per_hundred')
plt.show()

# %%
### Plot all data ######

# %%
data = pd.merge(vax_rates, trust_in_gov, on=["Country Name"])
data = pd.merge(data, gdp, on=["Country Name"])
data = pd.merge(data, secondary_edu, on=["Country Name"])
data = pd.merge(data, tert_edu, on=["Country Name"])
data = pd.merge(data, cov_deaths, on=["Country Name"])
data = pd.merge(data, health, on=["Country Name"])
data = pd.merge(data, life_exp, on=["Country Name"])
data = pd.merge(data, work, on=["Country Name"])
data = pd.merge(data, unemp, on=["Country Name"])
data
# Out:
#     Country Name  people_fully_vaccinated_per_hundred  \
# 0        Austria                                62.03
# 1        Austria                                62.03
# 2        Austria                                62.03
# 3        Austria                                62.03
# 4        Austria                                62.03
# ..           ...                                  ...
# 166       Turkey                                56.70
# 167       Turkey                                56.70
# 168       Turkey                                56.70
# 169       Turkey                                56.70
# 170       Turkey                                56.70
#
#      trust_in_government_2019  gdp_per_capita_2020  secondary_education_2019  \
# 0                   51.233826         55648.874565                    77.636
# 1                   51.233826         55648.874565                    77.636
# 2                   51.233826         55648.874565                    77.636
# 3                   51.233826         55648.874565                    77.636
# 4                   51.233826         55648.874565                    77.636
# ..                        ...                  ...                       ...
# 166                 56.126091         28113.736584                    76.235
# 167                 56.126091         28113.736584                    76.235
# 168                 56.126091         28113.736584                    76.235
# 169                 56.126091         28113.736584                    76.235
# 170                 56.126091         28113.736584                    76.235
#
#      tertiary_education_2019  Deaths/1M population  Self-reported_health_2019  \
# 0                     37.418                  1273                       70.0
# 1                     37.418                  1273                       70.0
# 2                     37.418                  1273                       70.0
# 3                     37.418                  1273                       70.0
# 4                     37.418                  1273                       70.0
# ..                       ...                   ...                        ...
# 166                   60.084                   847                       69.0
# 167                   60.084                   847                       69.0
# 168                   60.084                   847                       69.0
# 169                   60.084                   847                       69.0
# 170                   60.084                   847                       69.0
#
#      Life_expectancy_2019  Employees_working_hours_2019  unemployment_2020
# 0                    81.7                          6.66               5.77
# 1                    81.7                         10.01               5.77
# 2                    81.7                          3.10               5.77
# 3                    79.3                          6.66               5.77
# 4                    79.3                         10.01               5.77
# ..                    ...                           ...                ...
# 166                  75.3                         36.01              13.92
# 167                  75.3                         24.48              13.92
# 168                  80.7                         32.64              13.92
# 169                  80.7                         36.01              13.92
# 170                  80.7                         24.48              13.92
#
# [171 rows x 11 columns]

# %%
corrmat = data.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(data[["Employees_working_hours_2019", "Life_expectancy_2019", "Self-reported_health_2019","Deaths/1M population", "unemployment_2020","secondary_education_2019","trust_in_government_2019", "gdp_per_capita_2020", "people_fully_vaccinated_per_hundred"]].corr(),annot=True,cmap="RdYlGn")

# %%
#https://seaborn.pydata.org/generated/seaborn.pairplot.html#seaborn.pairplot

# %%
sns.pairplot(data, kind="hist")
